# %% [markdown]
# This Jupyter Notebook is meant to create the data visualization for our 3D Conceptual Risk-Scoring  Matrix Model, using Matplotlib with Python.
#
# Source/Credits: https://likegeeks.com/3d-plotting-in-python/

# %% [markdown]
# ## Importing Libraries

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Creating Figure and Axis, and plotting the point(s)

# %%
# Creating the empty figure
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='3d')

# Naming the figure & the axes 
ax.set_title("Risk Scoring Matrix")
ax.set_xlabel("Likelihood")
ax.set_ylabel("Severity")
ax.set_zlabel("Degree of Human Control")

# Setting the limits of each axes
ax.set_xlim(1,4)
ax.set_ylim(1,4)
ax.set_zlim(1,4)

# Setting the gridlines
ax.set_xticks([1,2,3,4])
ax.set_yticks([1,2,3,4])
ax.set_zticks([1,2,3,4])

# Plotting the points on the figure
# GREEN - Not likely, non severe, low deg 
ax.scatter(1,2,1, c='g')
ax.scatter(2,2,2, c='g') 
ax.scatter(2,1,2, c='g') 
ax.scatter(1,2,2, c='g') 
ax.scatter(2,2,1, c='g')
# AMBER - Likely, non severe, high deg
ax.scatter(4,1,4, c='#FFBF00') 
ax.scatter(3,1,4, c='#FFBF00') 
ax.scatter(4,1,3, c='#FFBF00') 
ax.scatter(4,1,3, c='#FFBF00') 
ax.scatter(3,1,3, c='#FFBF00') 
# RED - Likely, severe, high deg
ax.scatter(4,3,3, c='r') 
ax.scatter(3,4,3, c='r') 
ax.scatter(3,3,3, c='r') 
ax.scatter(4,3,4, c='r') 
ax.scatter(4,4,4, c='r')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# Comments:
# 1. [TO-DO] Colors for each points should be determined by certain logic (e.g. if vector values between (0,0,0) and (1,1,1) would be green etc)
# 2. [Good To Have] There should be some sort of annotations/labels when we over a data point
# 3. Float values supported by points - i.e. points can very well be (1.2, 3.1, 3.7) instead of (1,3,4)

# %% [markdown]
# # Testing out

# %%
import pandas as pd

# %%
df = pd.read_csv("Consolidated_News_Articles_With_Sentiment_Labels.csv")

df.head()
# Out:
#      date                   location  \
# 0  Feb-22          MUMBAI (REUTERS)
# 1  Feb-22          ZURICH (REUTERS)
# 2  Feb-22          VIENNA (REUTERS)
# 3  Feb-22       NEW DELHI (REUTERS)
# 4  Feb-21  SALT LAKE CITY (NYTIMES)
#
#                                           news title  \
# 0  Himalayan avalanche kills seven Indian soldier...
# 1  Eight killed in two days after third deadly av...
# 2  Avalanche in Austria near Swiss border kills five
# 3  Himalayan avalanche traps Indian Army patrol t...
# 4  4 skiers killed in avalanche in Utah, official...
#
#                                     news source(url)  \
# 0  https://www.straitstimes.com/asia/himalayan-av...
# 1  https://www.straitstimes.com/world/europe/eigh...
# 2  https://www.straitstimes.com/world/europe/aval...
# 3  https://www.straitstimes.com/asia/south-asia/h...
# 4  https://www.straitstimes.com/world/united-stat...
#
#                                      content summary  \
# 0  MUMBAI (REUTERS) - A Himalayan avalanche kille...
# 1  ZURICH (REUTERS) - One person was killed and f...
# 2  VIENNA (REUTERS) - An avalanche in an area of ...
# 3  NEW DELHI (REUTERS) - A Himalayan avalanche tr...
# 4  SALT LAKE CITY (NYTIMES) - Four back-country s...
#
#                                             keywords          class_name  \
# 0  kills, avalanche, defence, kameng, china, sold...  natural calamities
# 1  person, avalanche, tyrol, killed, days, skiers...  natural calamities
# 2  kills, avalanche, person, services, supervisor...  natural calamities
# 3  arunachal, avalanche, army, defence, team, chi...  natural calamities
# 4  avalanche, states, killed, skiers, saidthe, sa...  natural calamities
#
#       new_class_name                                  Preprocessed_Text  \
# 0  geophysical event  ['mumbai', 'reuters', 'himalayan', 'avalanche'...
# 1  geophysical event  ['zurich', 'reuters', 'one', 'person', 'killed...
# 2  geophysical event  ['vienna', 'reuters', 'avalanche', 'area', 'au...
# 3  geophysical event  ['new', 'delhi', 'reuters', 'himalayan', 'aval...
# 4  geophysical event  ['salt', 'lake', 'city', 'nytimes', 'four', 'b...
#
#                                   Preprocessed_Text2  \
# 0  mumbai reuters himalayan avalanche killed seve...
# 1  zurich reuters one person killed four others i...
# 2  vienna reuters avalanche area austria borderin...
# 3  new delhi reuters himalayan avalanche trapped ...
# 4  salt lake city nytimes four back country skier...
#
#                                      sentiment score  compound score  \
# 0  {'neg': 0.148, 'neu': 0.773, 'pos': 0.079, 'co...         -0.7506
# 1  {'neg': 0.276, 'neu': 0.63, 'pos': 0.094, 'com...         -0.9665
# 2  {'neg': 0.258, 'neu': 0.607, 'pos': 0.135, 'co...         -0.9100
# 3  {'neg': 0.045, 'neu': 0.782, 'pos': 0.172, 'co...          0.8225
# 4  {'neg': 0.258, 'neu': 0.703, 'pos': 0.039, 'co...         -0.9509
#
#   sentiment label
# 0        negative
# 1        negative
# 2        negative
# 3        positive
# 4        negative

# %%
df['new_class_name'].unique()
# Out:
# array(['geophysical event', 'idiosyncratic', 'cyberattack',
#        'Acute climatological event (cyclone)', 'pandemic',
#        'Acute climatological event (droughts)', 'Economic Crisis',
#        'Acute climatological event (flood)',
#        'Acute climatological event (heat stress)', 'Man-Made Disaster',
#        'Terrorism', 'Trade Dispute', 'Military Conflicts'], dtype=object)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def create_likelihood_score(x):
    if x == 'idiosyncratic':
        return 2
    elif x == 'geophysical event':
        return 3
    elif x == 'cyberattack':
        return 2
    elif x == 'Terrorism':
        return 3
    elif x == 'Military Conflicts':
        return 3
    elif x == 'Economic Crisis':
        return 4
    elif x == 'pandemic':
        return 4
    elif x == 'Trade Dispute':
        return 3
    elif x == 'Man-Made Disaster':
        return 3
    else:
        return 3

# %%
def create_severity_score(x):
    if x == 'idiosyncratic':
        return 4
    elif x == 'geophysical event':
        return 2
    elif x == 'cyberattack':
        return 4
    elif x == 'Terrorism':
        return 2
    elif x == 'Military Conflicts':
        return 3
    elif x == 'Economic Crisis':
        return 3
    elif x == 'pandemic':
        return 1
    elif x == 'Trade Dispute':
        return 2
    elif x == 'Man-Made Disaster':
        return 3
    else:
        return 3

# %%
def create_human_control_score(x):
    if x == 'idiosyncratic':
        return 3
    elif x == 'geophysical event':
        return 1
    elif x == 'cyberattack':
        return 2
    elif x == 'Terrorism':
        return 2
    elif x == 'Military Conflicts':
        return 3
    elif x == 'Economic Crisis':
        return 3
    elif x == 'pandemic':
        return 3
    elif x == 'Trade Dispute':
        return 4
    elif x == 'Man-Made Disaster':
        return 1
    else:
        return 3

# %%
df.head()
# Out:
#      date                   location  \
# 0  Feb-22          MUMBAI (REUTERS)
# 1  Feb-22          ZURICH (REUTERS)
# 2  Feb-22          VIENNA (REUTERS)
# 3  Feb-22       NEW DELHI (REUTERS)
# 4  Feb-21  SALT LAKE CITY (NYTIMES)
#
#                                           news title  \
# 0  Himalayan avalanche kills seven Indian soldier...
# 1  Eight killed in two days after third deadly av...
# 2  Avalanche in Austria near Swiss border kills five
# 3  Himalayan avalanche traps Indian Army patrol t...
# 4  4 skiers killed in avalanche in Utah, official...
#
#                                     news source(url)  \
# 0  https://www.straitstimes.com/asia/himalayan-av...
# 1  https://www.straitstimes.com/world/europe/eigh...
# 2  https://www.straitstimes.com/world/europe/aval...
# 3  https://www.straitstimes.com/asia/south-asia/h...
# 4  https://www.straitstimes.com/world/united-stat...
#
#                                      content summary  \
# 0  MUMBAI (REUTERS) - A Himalayan avalanche kille...
# 1  ZURICH (REUTERS) - One person was killed and f...
# 2  VIENNA (REUTERS) - An avalanche in an area of ...
# 3  NEW DELHI (REUTERS) - A Himalayan avalanche tr...
# 4  SALT LAKE CITY (NYTIMES) - Four back-country s...
#
#                                             keywords          class_name  \
# 0  kills, avalanche, defence, kameng, china, sold...  natural calamities
# 1  person, avalanche, tyrol, killed, days, skiers...  natural calamities
# 2  kills, avalanche, person, services, supervisor...  natural calamities
# 3  arunachal, avalanche, army, defence, team, chi...  natural calamities
# 4  avalanche, states, killed, skiers, saidthe, sa...  natural calamities
#
#       new_class_name                                  Preprocessed_Text  \
# 0  geophysical event  ['mumbai', 'reuters', 'himalayan', 'avalanche'...
# 1  geophysical event  ['zurich', 'reuters', 'one', 'person', 'killed...
# 2  geophysical event  ['vienna', 'reuters', 'avalanche', 'area', 'au...
# 3  geophysical event  ['new', 'delhi', 'reuters', 'himalayan', 'aval...
# 4  geophysical event  ['salt', 'lake', 'city', 'nytimes', 'four', 'b...
#
#                                   Preprocessed_Text2  \
# 0  mumbai reuters himalayan avalanche killed seve...
# 1  zurich reuters one person killed four others i...
# 2  vienna reuters avalanche area austria borderin...
# 3  new delhi reuters himalayan avalanche trapped ...
# 4  salt lake city nytimes four back country skier...
#
#                                      sentiment score  compound score  \
# 0  {'neg': 0.148, 'neu': 0.773, 'pos': 0.079, 'co...         -0.7506
# 1  {'neg': 0.276, 'neu': 0.63, 'pos': 0.094, 'com...         -0.9665
# 2  {'neg': 0.258, 'neu': 0.607, 'pos': 0.135, 'co...         -0.9100
# 3  {'neg': 0.045, 'neu': 0.782, 'pos': 0.172, 'co...          0.8225
# 4  {'neg': 0.258, 'neu': 0.703, 'pos': 0.039, 'co...         -0.9509
#
#   sentiment label
# 0        negative
# 1        negative
# 2        negative
# 3        positive
# 4        negative

# %%
df['Likelihood Score'] = df['new_class_name'].apply(create_likelihood_score)

# %%
df["Likelihood Score"].value_counts()
# Out:
# 3    9292
# 2    2437
# 4    2018
# Name: Likelihood Score, dtype: int64

# %%
df['Severity Score'] = df['new_class_name'].apply(create_severity_score)

# %%
df['Human Control Score'] = df['new_class_name'].apply(create_human_control_score)

# %%
df.head()
# Out:
#      date                   location  \
# 0  Feb-22          MUMBAI (REUTERS)
# 1  Feb-22          ZURICH (REUTERS)
# 2  Feb-22          VIENNA (REUTERS)
# 3  Feb-22       NEW DELHI (REUTERS)
# 4  Feb-21  SALT LAKE CITY (NYTIMES)
#
#                                           news title  \
# 0  Himalayan avalanche kills seven Indian soldier...
# 1  Eight killed in two days after third deadly av...
# 2  Avalanche in Austria near Swiss border kills five
# 3  Himalayan avalanche traps Indian Army patrol t...
# 4  4 skiers killed in avalanche in Utah, official...
#
#                                     news source(url)  \
# 0  https://www.straitstimes.com/asia/himalayan-av...
# 1  https://www.straitstimes.com/world/europe/eigh...
# 2  https://www.straitstimes.com/world/europe/aval...
# 3  https://www.straitstimes.com/asia/south-asia/h...
# 4  https://www.straitstimes.com/world/united-stat...
#
#                                      content summary  \
# 0  MUMBAI (REUTERS) - A Himalayan avalanche kille...
# 1  ZURICH (REUTERS) - One person was killed and f...
# 2  VIENNA (REUTERS) - An avalanche in an area of ...
# 3  NEW DELHI (REUTERS) - A Himalayan avalanche tr...
# 4  SALT LAKE CITY (NYTIMES) - Four back-country s...
#
#                                             keywords          class_name  \
# 0  kills, avalanche, defence, kameng, china, sold...  natural calamities
# 1  person, avalanche, tyrol, killed, days, skiers...  natural calamities
# 2  kills, avalanche, person, services, supervisor...  natural calamities
# 3  arunachal, avalanche, army, defence, team, chi...  natural calamities
# 4  avalanche, states, killed, skiers, saidthe, sa...  natural calamities
#
#       new_class_name                                  Preprocessed_Text  \
# 0  geophysical event  ['mumbai', 'reuters', 'himalayan', 'avalanche'...
# 1  geophysical event  ['zurich', 'reuters', 'one', 'person', 'killed...
# 2  geophysical event  ['vienna', 'reuters', 'avalanche', 'area', 'au...
# 3  geophysical event  ['new', 'delhi', 'reuters', 'himalayan', 'aval...
# 4  geophysical event  ['salt', 'lake', 'city', 'nytimes', 'four', 'b...
#
#                                   Preprocessed_Text2  \
# 0  mumbai reuters himalayan avalanche killed seve...
# 1  zurich reuters one person killed four others i...
# 2  vienna reuters avalanche area austria borderin...
# 3  new delhi reuters himalayan avalanche trapped ...
# 4  salt lake city nytimes four back country skier...
#
#                                      sentiment score  compound score  \
# 0  {'neg': 0.148, 'neu': 0.773, 'pos': 0.079, 'co...         -0.7506
# 1  {'neg': 0.276, 'neu': 0.63, 'pos': 0.094, 'com...         -0.9665
# 2  {'neg': 0.258, 'neu': 0.607, 'pos': 0.135, 'co...         -0.9100
# 3  {'neg': 0.045, 'neu': 0.782, 'pos': 0.172, 'co...          0.8225
# 4  {'neg': 0.258, 'neu': 0.703, 'pos': 0.039, 'co...         -0.9509
#
#   sentiment label  Likelihood Score  Severity Score  Human Control Score
# 0        negative                 3               2                    1
# 1        negative                 3               2                    1
# 2        negative                 3               2                    1
# 3        positive                 3               2                    1
# 4        negative                 3               2                    1

# %% [markdown]
# # Creating the Cube

# %%
threedee = plt.figure(figsize=(6,6)).gca(projection='3d')
# threedee.scatter(df['Likelihood Score'], df['Severity Score'], df['Human Control Score'], color ='r')
threedee.set_xlabel('Likelihood')
threedee.set_zlabel('Degree of Human Control')
threedee.set_ylabel('Severity')




for i in range(len(df)):
    likelihood_score = df["Likelihood Score"].loc[i]
    severity_score = df["New Severity Score"].loc[i]
    human_control_score = df["Human Control Score"].loc[i]
#     annotation = df["new_class_name"].loc[i]
    
    if likelihood_score <= 2:
#         print("Test!")
        if severity_score <= 2:
            threedee.scatter(likelihood_score, severity_score, human_control_score, c ='g')
        elif severity_score >= 3:
            threedee.scatter(likelihood_score, severity_score, human_control_score, c ='#FFBF00', marker = 'x')
    elif likelihood_score >= 3:
        if severity_score <= 2:
            threedee.scatter(likelihood_score, severity_score, human_control_score, c = '#FFBF00', marker = 'x')
        elif severity_score >= 3:
            threedee.scatter(likelihood_score, severity_score, human_control_score, c = 'r')
#             threedee.text(likelihood_score, severity_score, human_control_score,  '%s' % (annotation), size=10, zorder=1,  color='k') 
                
    
threedee.set_title("Risk Scoring Matrix")
# Setting the limits of each axes
threedee.set_xlim(0,4)
threedee.set_ylim(0,4)
threedee.set_zlim(0,4)

# Setting the gridlines
threedee.set_xticks([0,1,2,3,4])
threedee.set_yticks([0,1,2,3,4])
threedee.set_zticks([0,1,2,3,4])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# # Editing the Scores

# %%
df.head()
# Out:
#      date                   location  \
# 0  Feb-22          MUMBAI (REUTERS)
# 1  Feb-22          ZURICH (REUTERS)
# 2  Feb-22          VIENNA (REUTERS)
# 3  Feb-22       NEW DELHI (REUTERS)
# 4  Feb-21  SALT LAKE CITY (NYTIMES)
#
#                                           news title  \
# 0  Himalayan avalanche kills seven Indian soldier...
# 1  Eight killed in two days after third deadly av...
# 2  Avalanche in Austria near Swiss border kills five
# 3  Himalayan avalanche traps Indian Army patrol t...
# 4  4 skiers killed in avalanche in Utah, official...
#
#                                     news source(url)  \
# 0  https://www.straitstimes.com/asia/himalayan-av...
# 1  https://www.straitstimes.com/world/europe/eigh...
# 2  https://www.straitstimes.com/world/europe/aval...
# 3  https://www.straitstimes.com/asia/south-asia/h...
# 4  https://www.straitstimes.com/world/united-stat...
#
#                                      content summary  \
# 0  MUMBAI (REUTERS) - A Himalayan avalanche kille...
# 1  ZURICH (REUTERS) - One person was killed and f...
# 2  VIENNA (REUTERS) - An avalanche in an area of ...
# 3  NEW DELHI (REUTERS) - A Himalayan avalanche tr...
# 4  SALT LAKE CITY (NYTIMES) - Four back-country s...
#
#                                             keywords          class_name  \
# 0  kills, avalanche, defence, kameng, china, sold...  natural calamities
# 1  person, avalanche, tyrol, killed, days, skiers...  natural calamities
# 2  kills, avalanche, person, services, supervisor...  natural calamities
# 3  arunachal, avalanche, army, defence, team, chi...  natural calamities
# 4  avalanche, states, killed, skiers, saidthe, sa...  natural calamities
#
#       new_class_name                                  Preprocessed_Text  \
# 0  geophysical event  ['mumbai', 'reuters', 'himalayan', 'avalanche'...
# 1  geophysical event  ['zurich', 'reuters', 'one', 'person', 'killed...
# 2  geophysical event  ['vienna', 'reuters', 'avalanche', 'area', 'au...
# 3  geophysical event  ['new', 'delhi', 'reuters', 'himalayan', 'aval...
# 4  geophysical event  ['salt', 'lake', 'city', 'nytimes', 'four', 'b...
#
#                                   Preprocessed_Text2  \
# 0  mumbai reuters himalayan avalanche killed seve...
# 1  zurich reuters one person killed four others i...
# 2  vienna reuters avalanche area austria borderin...
# 3  new delhi reuters himalayan avalanche trapped ...
# 4  salt lake city nytimes four back country skier...
#
#                                      sentiment score  compound score  \
# 0  {'neg': 0.148, 'neu': 0.773, 'pos': 0.079, 'co...         -0.7506
# 1  {'neg': 0.276, 'neu': 0.63, 'pos': 0.094, 'com...         -0.9665
# 2  {'neg': 0.258, 'neu': 0.607, 'pos': 0.135, 'co...         -0.9100
# 3  {'neg': 0.045, 'neu': 0.782, 'pos': 0.172, 'co...          0.8225
# 4  {'neg': 0.258, 'neu': 0.703, 'pos': 0.039, 'co...         -0.9509
#
#   sentiment label  Likelihood Score  Severity Score  Human Control Score
# 0        negative                 3               2                    1
# 1        negative                 3               2                    1
# 2        negative                 3               2                    1
# 3        positive                 3               2                    1
# 4        negative                 3               2                    1

# %%
for i in range(len(df)):
    severity_score = df["Severity Score"].loc[i]
    sentiment_label = df["sentiment label"].loc[i]
    compound_score = df["compound score"].loc[i]
    
#     print(compound_score)
    
    if sentiment_label == "negative":
#         print(compound_score)
        compound_score = -compound_score
        test = compound_score * severity_score
        print(f"{sentiment_label}: {test}")
        df["New Severity Score"].loc[i] = test
    elif sentiment_label == "positive":
        test = compound_score * severity_score
        print(f"{sentiment_label}: {test}")
        df["New Severity Score"].loc[i] = compound_score * severity_score
    elif sentiment_label == "neutral":
#         test = compound_score * severity_score
        print(f"{sentiment_label}: {severity_score}")
        df["New Severity Score"].loc[i] = severity_score
# Out:
# negative: 1.5012
# negative: 1.933
# negative: 1.82
# positive: 1.645
# negative: 1.9018
# neutral: 2
# positive: 1.82
# positive: 1.475
# neutral: 2
# neutral: 2
# neutral: 2
# negative: 1.8826
# negative: 1.892
# negative: 1.0846
# negative: 1.0534
# negative: 1.777
# positive: 1.3816
# negative: 1.8516
# negative: 1.9142
# negative: 1.8598
# negative: 1.8864
# neutral: 2
# negative: 1.1718
# neutral: 2
# negative: 1.9356
# negative: 1.3616
# negative: 1.8272
# positive: 1.2248
# negative: 1.486
# neutral: 2
# neutral: 2
# negative: 1.486
# positive: 1.6252
# negative: 1.7378
# positive: 1.604
# negative: 1.4702
# negative: 1.918
# negative: 1.4538
# neutral: 2
# negative: 1.95
# negative: 1.9214
# negative: 1.7668
# negative: 1.8574
# positive: 1.8574
# neutral: 2
# neutral: 2
# negative: 1.569
# negative: 1.772
# positive: 1.2248
# positive: 1.86
# negative: 1.1148
# neutral: 2
# negative: 1.8674
# positive: 1.1718
# negative: 1.7868
# negative: 1.934
# neutral: 2
# neutral: 2
# negative: 1.8402
# neutral: 2
# negative: 1.6542
# negative: 1.892
# negative: 1.9464
# negative: 1.7558
# positive: 1.5012
# negative: 1.9672
# negative: 1.9076
# positive: 1.5812
# negative: 1.8372
# neutral: 2
# positive: 1.8236
# negative: 1.6632
# neutral: 2
# negative: 1.645
# negative: 1.8272
# neutral: 2
# positive: 1.2498
# negative: 1.9418
# neutral: 2
# negative: 1.744
# negative: 1.9566
# neutral: 2
# positive: 1.4368
# neutral: 2
# positive: 1.3194
# negative: 1.9104
# neutral: 2
# positive: 1.4006
# positive: 1.8846
# negative: 1.7668
# neutral: 2
# positive: 1.9048
# negative: 1.4006
# negative: 1.2284
# negative: 1.8642
# positive: 1.0846
# negative: 1.9488
# neutral: 2
# neutral: 2
# negative: 1.782
# negative: 1.9076
# negative: 1.2738
# negative: 1.9076
# positive: 1.8124
# negative: 1.9838
# negative: 1.0212
# neutral: 2
# negative: 1.9202
# negative: 1.782
# positive: 1.3616
# neutral: 2
# neutral: 2
# negative: 1.5812
# neutral: 2
# positive: 1.9202
# negative: 1.1988
# positive: 1.569
# negative: 1.772
# negative: 1.872
# negative: 1.6352
# positive: 1.1988
# negative: 1.6214
# negative: 1.8002
# positive: 1.3616
# negative: 1.5434
# negative: 1.7038
# neutral: 2
# negative: 1.604
# neutral: 2
# negative: 1.604
# neutral: 2
# negative: 1.7278
# negative: 1.961
# negative: 1.9272
# negative: 1.8236
# negative: 1.8338
# negative: 1.4538
# neutral: 2
# positive: 1.9156
# positive: 1.9246
# negative: 1.672
# positive: 1.8402
# negative: 1.9142
# positive: 1.8124
# positive: 1.8124
# positive: 1.583
# neutral: 2
# positive: 1.7958
# neutral: 2
# negative: 1.4192
# negative: 1.604
# negative: 1.9266
# negative: 1.8434
# negative: 1.1876
# negative: 1.8806
# positive: 1.6542
# negative: 1.8936
# negative: 1.1876
# neutral: 2
# negative: 1.865
# negative: 1.645
# positive: 1.0846
# neutral: 2
# positive: 1.1148
# positive: 1.1148
# negative: 1.6352
# positive: 1.75
# neutral: 2
# negative: 1.5012
# neutral: 2
# negative: 1.772
# neutral: 2
# negative: 1.5158
# positive: 1.6542
# negative: 1.892
# neutral: 2
# positive: 1.8376
# negative: 1.1418
# negative: 1.9052
# positive: 1.8764
# neutral: 2
# positive: 1.6252
# positive: 1.53
# negative: 1.9784
# neutral: 2
# negative: 1.53
# neutral: 2
# positive: 1.1438
# negative: 1.672
# negative: 1.1126
# neutral: 2
# negative: 1.2972
# negative: 1.672
# positive: 1.9168
# neutral: 2
# positive: 1.8462
# positive: 1.6884
# neutral: 2
# positive: 1.2498
# negative: 1.1438
# negative: 1.3616
# positive: 1.5434
# neutral: 2
# negative: 1.7316
# positive: 1.5566
# positive: 1.2972
# negative: 1.604
# positive: 1.909
# positive: 1.909
# negative: 1.5012
# positive: 1.498
# positive: 1.292
# neutral: 2
# negative: 1.0534
# positive: 1.5158
# positive: 1.5566
# negative: 1.1718
# negative: 1.1718
# negative: 1.8954
# neutral: 2
# negative: 1.9424
# positive: 1.53
# negative: 1.9528
# positive: 1.7378
# positive: 1.8864
# positive: 1.725
# positive: 1.725
# negative: 1.919
# neutral: 2
# positive: 1.1988
# negative: 1.886
# positive: 1.9552
# C:\Users\Darren\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# positive: 1.8272
# positive: 1.3616
# positive: 1.3816
# positive: 1.8056
# positive: 1.8056
# positive: 1.8986
# negative: 1.82
# negative: 1.7668
# positive: 1.5812
# positive: 1.4382
# positive: 1.9202
# positive: 1.5566
# positive: 1.8462
# negative: 1.7914
# negative: 1.9488
# negative: 1.9566
# neutral: 2
# positive: 1.852
# neutral: 2
# positive: 1.8162
# negative: 1.6542
# negative: 1.8674
# positive: 1.5928
# negative: 1.9438
# neutral: 2
# negative: 1.8402
# positive: 1.7316
# positive: 1.7868
# neutral: 2
# positive: 1.7914
# negative: 1.7614
# negative: 1.2498
# positive: 1.9216
# neutral: 2
# positive: 1.2972
# negative: 1.9864
# negative: 1.9372
# negative: 1.9332
# negative: 1.8826
# positive: 1.2972
# neutral: 2
# negative: 1.9002
# negative: 1.8764
# negative: 1.6148
# negative: 1.9332
# positive: 1.2248
# negative: 1.897
# neutral: 2
# negative: 1.9632
# negative: 1.9458
# neutral: 2
# neutral: 2
# neutral: 2
# neutral: 2
# positive: 1.1148
# positive: 1.8044
# negative: 1.9288
# neutral: 2
# negative: 1.9656
# positive: 1.0106
# positive: 1.9622
# negative: 1.8236
# neutral: 2
# positive: 1.2498
# negative: 1.9728
# negative: 1.9488
# neutral: 2
# positive: 1.772
# neutral: 2
# negative: 1.0534
# neutral: 2
# neutral: 2
# negative: 1.725
# neutral: 2
# neutral: 2
# neutral: 2
# negative: 1.744
# positive: 1.2498
# neutral: 2
# positive: 1.3816
# positive: 1.8492
# neutral: 2
# positive: 1.8492
# negative: 1.5894
# negative: 1.9682
# neutral: 2
# neutral: 2
# positive: 1.9034
# positive: 1.529
# neutral: 2
# neutral: 2
# negative: 1.7038
# negative: 1.8124
# negative: 1.5812
# positive: 1.725
# negative: 1.9396
# negative: 1.8162
# negative: 1.8124
# positive: 1.744
# positive: 1.772
# negative: 1.9464
# negative: 1.8674
# neutral: 2
# positive: 1.1718
# positive: 1.569
# neutral: 2
# neutral: 2
# positive: 1.9446
# positive: 1.1148
# neutral: 2
# negative: 1.8338
# positive: 1.6252
# negative: 1.8764
# negative: 1.8806
# neutral: 2
# negative: 1.9276
# neutral: 2
# negative: 1.6878
# positive: 1.82
# positive: 1.4702
# negative: 1.6804
# negative: 1.9458
# positive: 1.9562
# positive: 1.6352
# neutral: 2
# negative: 1.53
# neutral: 2
# neutral: 2
# negative: 1.3026
# negative: 1.9076
# negative: 1.5012
# negative: 1.4192
# negative: 1.5812
# neutral: 2
# negative: 1.1658
# positive: 1.433
# positive: 1.1148
# neutral: 2
# neutral: 2
# negative: 1.744
# negative: 1.8084
# positive: 1.9202
# negative: 1.1148
# negative: 1.9168
# positive: 1.7868
# positive: 1.1458
# neutral: 2
# positive: 1.1438
# positive: 1.9168
# negative: 1.2972
# neutral: 2
# positive: 1.8864
# positive: 1.6352
# positive: 1.8574
# negative: 1.86
# negative: 1.9466
# neutral: 2
# positive: 1.7914
# positive: 1.2738
# neutral: 2
# neutral: 2
# negative: 1.0212
# neutral: 2
# positive: 1.7558
# positive: 1.9348
# neutral: 2
# positive: 1.744
# negative: 1.2738
# negative: 1.9168
# negative: 1.2738
# neutral: 2
# negative: 1.0512
# negative: 1.1988
# negative: 1.7182
# negative: 1.6542
# negative: 1.9296
# neutral: 2
# positive: 1.9602
# positive: 1.9034
# positive: 1.1148
# neutral: 2
# positive: 1.9454
# negative: 1.9356
# negative: 1.9658
# negative: 1.9602
# negative: 1.9658
# negative: 1.6252
# positive: 1.1438
# negative: 1.9346
# negative: 1.897
# negative: 1.486
# positive: 1.8712
# neutral: 2
# positive: 1.4006
# negative: 1.6962
# negative: 1.9858
# neutral: 2
# positive: 1.6962
# negative: 1.8306
# negative: 1.1988
# positive: 1.7116
# neutral: 2
# positive: 1.4538
# negative: 1.8306
# positive: 1.5012
# negative: 1.1148
# negative: 1.7378
# neutral: 2
# positive: 1.7958
# positive: 1.7798
# positive: 1.2972
# negative: 1.6252
# negative: 1.9828
# negative: 1.341
# negative: 1.8698
# negative: 1.569
# negative: 1.8698
# neutral: 2
# negative: 1.7246
# negative: 1.8306
# negative: 1.8044
# neutral: 2
# neutral: 2
# neutral: 2
# neutral: 2
# negative: 1.9388
# neutral: 2
# neutral: 2
# negative: 1.9482
# positive: 1.8326
# neutral: 2
# neutral: 2
# positive: 1.8002
# negative: 1.341
# negative: 1.772
# positive: 1.0534
# negative: 1.4538
# negative: 1.569
# negative: 1.777
# negative: 1.2972
# neutral: 2
# negative: 1.3616
# positive: 1.9266
# positive: 1.7774
# negative: 1.7588
# positive: 1.6252
# positive: 1.6572
# negative: 1.6442
# positive: 1.82
# neutral: 2
# negative: 1.4538
# negative: 1.9616
# positive: 1.909
# neutral: 2
# neutral: 2
# negative: 1.2266
# positive: 1.2248
# negative: 1.9296
# neutral: 2
# positive: 1.7614
# positive: 1.8272
# neutral: 2
# positive: 1.8806
# positive: 1.2738
# neutral: 2
# negative: 1.75
# negative: 1.9168
# negative: 1.2088
# neutral: 2
# negative: 1.5434
# positive: 1.486
# neutral: 2
# positive: 1.4702
# negative: 1.9662
# negative: 1.9752
# negative: 1.3616
# negative: 1.8492
# negative: 1.9404
# neutral: 2
# negative: 1.2738
# neutral: 2
# negative: 1.0212
# negative: 1.5012
# neutral: 2
# negative: 3.344
# negative: 3.3924
# neutral: 4
# neutral: 4
# neutral: 4
# negative: 3.0316
# negative: 3.5228
# neutral: 4
# neutral: 4
# negative: 3.3264
# negative: 3.8552
# positive: 2.1068
# negative: 3.6544
# neutral: 4
# neutral: 4
# neutral: 4
# positive: 2.2876
# positive: 2.5944
# positive: 2.2296
# negative: 2.1068
# neutral: 4
# negative: 3.06
# neutral: 4
# negative: 3.7528
# positive: 2.3436
# negative: 2.2296
# positive: 3.5228
# negative: 2.0424
# negative: 3.1132
# neutral: 4
# negative: 3.8236
# positive: 2.7232
# neutral: 4
# positive: 3.5336
# neutral: 4
# negative: 3.3924
# neutral: 4
# positive: 3.488
# negative: 2.1144
# negative: 3.7448
# neutral: 4
# negative: 3.4364
# neutral: 4
# positive: 3.0024
# positive: 3.6048
# neutral: 4
# negative: 3.5116
# neutral: 4
# neutral: 4
# negative: 3.0024
# negative: 3.6804
# negative: 2.1692
# positive: 3.7652
# negative: 2.3976
# positive: 2.682
# positive: 3.8492
# neutral: 4
# positive: 2.9076
# neutral: 4
# neutral: 4
# neutral: 4
# negative: 2.5476
# positive: 3.06
# positive: 3.1132
# neutral: 4
# negative: 3.6984
# positive: 3.0024
# positive: 3.7148
# positive: 3.7804
# negative: 3.3084
# negative: 3.704
# positive: 3.744
# negative: 3.3264
# positive: 3.422
# neutral: 4
# negative: 3.29
# negative: 3.2504
# neutral: 4
# neutral: 4
# negative: 3.6612
# negative: 3.5504
# neutral: 4
# negative: 3.8552
# neutral: 4
# positive: 2.6624
# neutral: 4
# positive: 3.6984
# neutral: 4
# neutral: 4
# negative: 3.7296
# neutral: 4
# negative: 3.6676
# negative: 2.0424
# positive: 3.838
# positive: 3.5736
# positive: 2.8384
# neutral: 4
# negative: 3.5336
# neutral: 4
# negative: 3.73
# negative: 3.8036
# neutral: 4
# negative: 3.1624
# neutral: 4
# positive: 3.7728
# negative: 3.29
# negative: 3.0048
# neutral: 4
# positive: 3.3252
# neutral: 4
# negative: 3.3804
# neutral: 4
# neutral: 4
# neutral: 4
# positive: 3.5736
# negative: 2.9404
# negative: 3.6544
# negative: 2.1692
# neutral: 4
# positive: 3.3924
# positive: 3.5228
# positive: 3.4364
# neutral: 4
# positive: 2.3976
# positive: 2.6624
# negative: 2.0424
# positive: 3.5116
# neutral: 4
# neutral: 4
# negative: 2.8736
# negative: 3.1624
# neutral: 4
# negative: 2.3436
# neutral: 4
# negative: 3.922
# positive: 2.7632
# neutral: 4
# neutral: 4
# neutral: 4
# neutral: 4
# neutral: 4
# positive: 2.7232
# positive: 2.4496
# neutral: 4
# negative: 3.4632
# negative: 3.6868
# positive: 2.5944
# negative: 2.5944
# negative: 3.3608
# negative: 3.7396
# negative: 3.9344
# neutral: 4
# positive: 3.29
# neutral: 4
# negative: 3.1224
# negative: 2.3976
# neutral: 4
# positive: 2.4496
# neutral: 4
# neutral: 4
# neutral: 4
# positive: 2.972
# negative: 3.6324
# positive: 3.0868
# neutral: 4
# positive: 3.7804
# negative: 2.5476
# negative: 3.6804
# negative: 2.2208
# negative: 3.9116
# neutral: 4
# neutral: 4
# positive: 3.3924
# positive: 3.0496
# negative: 3.8208
# neutral: 4
# negative: 2.8736
# negative: 3.3084
# positive: 2.972
# negative: 2.5944
# neutral: 4
# neutral: 4
# positive: 3.4364
# positive: 3.5228
# negative: 3.5728
# neutral: 4
# positive: 2.3436
# neutral: 4
# negative: 2.8736
# positive: 3.9272
# positive: 3.3768
# neutral: 4
# negative: 2.8736
# positive: 2.7232
# negative: 3.138
# positive: 3.5116
# negative: 2.5944
# negative: 2.2876
# negative: 2.7632
# neutral: 4
# negative: 3.8404
# negative: 3.5
# negative: 3.8928
# negative: 2.7232
# negative: 3.6924
# neutral: 4
# neutral: 4
# negative: 3.5828
# negative: 3.8036
# neutral: 4
# negative: 3.8404
# negative: 2.4384
# negative: 3.0316
# positive: 2.2876
# positive: 2.2876
# negative: 3.8068
# positive: 2.1248
# neutral: 4
# positive: 2.6388
# positive: 2.6388
# neutral: 4
# positive: 3.6004
# negative: 3.4212
# neutral: 4
# negative: 3.7252
# negative: 3.45
# negative: 3.64
# negative: 3.6004
# positive: 2.5508
# negative: 3.4756
# positive: 3.488
# positive: 2.5944
# neutral: 4
# positive: 3.6544
# neutral: 4
# negative: 3.344
# negative: 3.5468
# positive: 2.2876
# positive: 2.5476
# neutral: 4
# positive: 2.0424
# negative: 3.6248
# negative: 3.9144
# negative: 3.6676
# negative: 3.7396
# neutral: 4
# neutral: 4
# positive: 2.0424
# positive: 2.0424
# negative: 2.4996
# positive: 3.5228
# positive: 3.6984
# neutral: 4
# negative: 3.06
# positive: 3.6324
# positive: 3.1624
# positive: 3.5736
# negative: 2.4496
# negative: 3.574
# neutral: 4
# positive: 2.6388
# positive: 3.3264
# neutral: 4
# neutral: 4
# neutral: 4
# negative: 2.7632
# positive: 2.854
# neutral: 4
# neutral: 4
# neutral: 4
# neutral: 4
# positive: 3.0024
# positive: 3.3264
# positive: 3.5336
# neutral: 4
# negative: 3.29
# positive: 3.8336
# neutral: 4
# positive: 3.3084
# positive: 2.2876
# negative: 3.208
# negative: 3.9084
# positive: 3.3084
# negative: 2.2876
# neutral: 4
# neutral: 4
# negative: 3.4632
# neutral: 4
# positive: 3.8284
# negative: 3.9032
# neutral: 4
# negative: 3.2504
# neutral: 4
# neutral: 4
# positive: 3.2504
# negative: 3.2504
# negative: 2.8012
# neutral: 4
# positive: 3.544
# positive: 3.6248
# negative: 2.3584
# positive: 3.2504
# positive: 3.5228
# positive: 2.9404
# neutral: 4
# positive: 3.9452
# neutral: 4
# negative: 3.45
# positive: 3.1132
# neutral: 4
# negative: 3.8336
# negative: 3.64
# positive: 3.344
# positive: 3.8696
# positive: 2.3436
# positive: 3.2704
# positive: 3.5108
# neutral: 4
# negative: 3.876
# positive: 3.0024
# positive: 2.9076
# positive: 2.0424
# negative: 3.73
# negative: 3.7148
# neutral: 4
# negative: 3.5336
# positive: 3.7652
# positive: 2.8012
# neutral: 4
# neutral: 4
# positive: 3.2504
# neutral: 4
# negative: 2.9404
# positive: 3.0868
# positive: 3.3084
# neutral: 4
# negative: 3.208
# negative: 3.7728
# positive: 3.1132
# negative: 3.794
# negative: 2.8384
# negative: 2.8012
# negative: 3.4756
# neutral: 4
# negative: 2.1068
# neutral: 4
# positive: 2.2876
# positive: 3.9116
# neutral: 4
# negative: 3.9248
# negative: 2.1692
# negative: 3.7032
# positive: 3.7804
# negative: 2.4496
# negative: 3.6524
# neutral: 4
# negative: 2.9404
# negative: 3.7148
# negative: 3.818
# positive: 3.8608
# negative: 2.1816
# neutral: 4
# positive: 2.3976
# positive: 3.9496
# neutral: 4
# positive: 3.3924
# negative: 2.7632
# negative: 3.564
# neutral: 4
# positive: 2.5944
# negative: 3.7572
# negative: 3.8312
# positive: 3.7768
# negative: 3.5916
# positive: 3.96
# positive: 2.9076
# neutral: 4
# negative: 2.0424
# positive: 3.8512
# negative: 3.72
# positive: 3.8744
# negative: 3.2248
# positive: 2.5476
# neutral: 4
# negative: 2.4996
# positive: 3.5828
# neutral: 4
# positive: 3.9272
# negative: 3.0896
# neutral: 4
# positive: 2.9404
# negative: 2.4996
# positive: 3.544
# negative: 3.1132
# negative: 3.138
# positive: 2.5476
# negative: 3.3924
# negative: 3.344
# negative: 2.4496
# neutral: 4
# positive: 3.6168
# negative: 3.4756
# negative: 2.9404
# neutral: 4
# negative: 3.5
# positive: 2.5944
# neutral: 4
# negative: 3.8988
# negative: 3.29
# negative: 3.4076
# negative: 3.2296
# neutral: 4
# neutral: 4
# neutral: 4
# neutral: 4
# negative: 2.8012
# neutral: 4
# positive: 2.5476
# positive: 3.73
# negative: 3.794
# negative: 3.5828
# negative: 3.1856
# negative: 3.4756
# neutral: 4
# negative: 2.2876
# positive: 2.8384
# neutral: 4
# negative: 3.8068
# positive: 3.344
# neutral: 4
# negative: 2.3436
# negative: 3.228
# negative: 3.554
# neutral: 4
# negative: 3.138
# negative: 3.4364
# neutral: 4
# negative: 3.7148
# negative: 3.488
# negative: 3.6004
# neutral: 4
# neutral: 4
# negative: 2.6388
# negative: 2.8012
# positive: 3.8428
# negative: 3.8512
# negative: 3.8728
# neutral: 4
# negative: 3.3768
# positive: 3.6088
# negative: 3.744
# negative: 2.1692
# negative: 2.7632
# negative: 3.6004
# neutral: 4
# positive: 3.5336
# negative: 3.5336
# negative: 3.554
# positive: 2.3436
# negative: 3.1132
# positive: 3.2704
# positive: 3.1624
# neutral: 4
# negative: 3.29
# neutral: 4
# negative: 3.6472
# neutral: 4
# negative: 3.5
# negative: 2.5648
# negative: 3.3924
# negative: 3.138
# positive: 3.5
# negative: 2.9076
# neutral: 4
# positive: 2.1068
# negative: 2.6388
# negative: 3.8808
# neutral: 4
# negative: 2.4496
# neutral: 4
# positive: 3.208
# positive: 3.3608
# negative: 3.6324
# positive: 3.1352
# positive: 3.8532
# neutral: 4
# positive: 3.4756
# negative: 2.7232
# positive: 3.6612
# neutral: 4
# negative: 3.8808
# negative: 2.2876
# negative: 3.544
# positive: 3.9084
# positive: 3.9248
# negative: 2.8012
# negative: 3.876
# negative: 3.208
# neutral: 4
# neutral: 4
# negative: 3.06
# neutral: 4
# positive: 3.73
# positive: 3.6544
# neutral: 4
# negative: 3.894
# neutral: 4
# negative: 3.1624
# positive: 2.9076
# positive: 2.4496
# negative: 2.0424
# negative: 2.066
# neutral: 4
# neutral: 4
# positive: 3.0316
# negative: 3.0024
# neutral: 4
# negative: 2.2876
# neutral: 4
# negative: 3.826
# negative: 3.3608
# neutral: 4
# neutral: 4
# neutral: 4
# neutral: 4
# negative: 3.7768
# neutral: 4
# negative: 2.9076
# positive: 2.0424
# negative: 3.1856
# negative: 3.3924
# positive: 2.5944
# positive: 2.8384
# negative: 2.5944
# negative: 3.7096
# positive: 3.3084
# positive: 3.208
# positive: 3.8552
# neutral: 4
# positive: 3.7348
# negative: 2.7632
# negative: 2.2876
# negative: 3.8036
# negative: 3.0024
# negative: 3.826
# neutral: 4
# negative: 3.6248
# negative: 3.554
# neutral: 4
# negative: 2.4496
# negative: 2.0424
# neutral: 4
# negative: 3.7728
# negative: 3.8644
# neutral: 4
# positive: 3.3264
# positive: 2.4996
# positive: 2.972
# positive: 3.0316
# negative: 3.5156
# negative: 2.2876
# negative: 3.6324
# negative: 3.5336
# neutral: 4
# positive: 3.5336
# positive: 2.2296
# negative: 3.4076
# negative: 2.2876
# negative: 3.564
# negative: 3.6324
# positive: 2.9404
# negative: 3.8504
# positive: 2.7716
# neutral: 4
# negative: 3.488
# negative: 3.488
# negative: 3.4076
# negative: 2.3436
# negative: 2.3436
# positive: 2.3436
# neutral: 4
# negative: 3.4076
# negative: 2.468
# positive: 3.066
# negative: 3.4632
# neutral: 4
# neutral: 4
# negative: 2.6388
# negative: 2.2876
# negative: 2.4996
# positive: 3.5736
# positive: 3.6924
# negative: 3.8532
# negative: 3.9372
# positive: 2.6388
# neutral: 4
# negative: 3.0316
# neutral: 4
# neutral: 4
# negative: 2.2876
# neutral: 4
# neutral: 4
# negative: 3.564
# negative: 2.7632
# positive: 2.682
# negative: 3.8068
# negative: 3.2704
# positive: 3.818
# negative: 2.8384
# positive: 3.7768
# negative: 3.6472
# positive: 3.744
# positive: 3.744
# neutral: 4
# neutral: 4
# neutral: 4
# negative: 3.1624
# negative: 3.1572
# neutral: 4
# neutral: 4
# negative: 3.1132
# neutral: 4
# positive: 2.2876
# neutral: 4
# negative: 3.814
# negative: 2.3976
# negative: 3.8068
# negative: 3.1132
# positive: 3.4076
# negative: 3.6984
# neutral: 4
# negative: 3.794
# negative: 3.838
# neutral: 4
# negative: 2.2296
# negative: 3.7728
# neutral: 4
# negative: 3.72
# positive: 3.826
# positive: 2.7632
# positive: 2.1068
# neutral: 4
# negative: 3.4076
# positive: 2.3976
# negative: 3.64
# positive: 3.8988
# positive: 3.9028
# positive: 3.7908
# negative: 3.1624
# negative: 2.682
# negative: 3.6744
# negative: 3.7252
# positive: 2.2876
# positive: 3.7252
# positive: 3.5116
# negative: 3.7252
# negative: 3.936
# neutral: 4
# neutral: 4
# negative: 3.8628
# negative: 3.8068
# neutral: 4
# negative: 3.6984
# negative: 3.0868
# positive: 2.972
# neutral: 4
# negative: 3.2704
# negative: 3.2704
# negative: 3.7348
# positive: 3.704
# negative: 3.344
# negative: 3.6472
# negative: 3.5736
# positive: 3.8152
# negative: 3.704
# negative: 3.3264
# negative: 3.6248
# positive: 2.5476
# neutral: 4
# negative: 3.7872
# negative: 3.3008
# positive: 2.9404
# negative: 3.8728
# negative: 3.4076
# positive: 2.2296
# negative: 3.3084
# negative: 2.8384
# negative: 3.8848
# positive: 2.8736
# neutral: 4
# negative: 3.8876
# positive: 3.6544
# positive: 2.2296
# positive: 3.45
# negative: 2.3976
# positive: 2.5944
# negative: 2.2296
# positive: 3.138
# positive: 2.8012
# positive: 3.73
# positive: 3.1856
# neutral: 4
# negative: 2.8012
# neutral: 4
# negative: 3.8696
# positive: 3.344
# neutral: 4
# neutral: 4
# negative: 2.3976
# positive: 3.0868
# positive: 2.4496
# positive: 3.8448
# negative: 2.1068
# negative: 2.9076
# positive: 2.8736
# positive: 2.6328
# positive: 3.818
# negative: 3.6924
# positive: 3.8036
# neutral: 4
# neutral: 4
# neutral: 4
# positive: 3.8664
# negative: 3.9012
# negative: 3.6472
# positive: 3.4632
# negative: 3.2504
# negative: 3.8608
# positive: 3.5116
# positive: 3.4364
# positive: 2.0564
# positive: 3.7252
# negative: 3.9104
# neutral: 4
# positive: 3.0024
# negative: 3.4364
# negative: 2.4996
# positive: 2.4996
# positive: 3.1856
# positive: 3.5916
# positive: 3.422
# neutral: 4
# positive: 3.5
# negative: 3.8152
# negative: 3.7728
# neutral: 4
# neutral: 4
# neutral: 4
# neutral: 4
# positive: 3.5916
# positive: 3.9152
# negative: 3.0316
# negative: 2.7232
# neutral: 4
# positive: 3.4756
# negative: 3.0868
# neutral: 4
# negative: 3.9216
# negative: 3.7692
# negative: 2.682
# positive: 2.682
# negative: 3.72
# negative: 3.8532
# neutral: 4
# negative: 3.45
# neutral: 4
# neutral: 4
# positive: 2.4996
# negative: 3.3264
# negative: 3.29
# negative: 3.7768
# negative: 3.8036
# negative: 3.0316
# negative: 3.2504
# neutral: 4
# negative: 2.8384
# positive: 3.0024
# negative: 3.8644
# positive: 2.7232
# negative: 3.9096
# neutral: 4
# positive: 3.544
# positive: 2.9076
# positive: 3.6612
# negative: 3.8552
# positive: 3.8208
# neutral: 4
# positive: 3.6924
# neutral: 4
# positive: 3.6168
# negative: 3.4632
# negative: 3.7972
# positive: 3.9732
# positive: 3.5828
# positive: 2.1692
# neutral: 4
# negative: 3.7692
# negative: 3.3608
# positive: 3.2704
# negative: 3.554
# negative: 3.5116
# neutral: 4
# negative: 3.704
# positive: 2.2876
# positive: 3.826
# negative: 3.6164
# positive: 2.2296
# positive: 3.9032
# positive: 3.6984
# positive: 3.8236
# positive: 3.6612
# positive: 2.2296
# negative: 3.3084
# positive: 3.7348
# negative: 3.4756
# negative: 2.682
# negative: 2.8384
# positive: 3.7096
# positive: 3.7908
# neutral: 4
# positive: 2.0424
# negative: 3.8864
# neutral: 4
# negative: 3.8312
# neutral: 4
# neutral: 4
# negative: 3.9316
# negative: 3.8124
# negative: 2.1068
# negative: 3.5916
# positive: 3.2504
# positive: 3.7872
# negative: 2.4996
# positive: 3.8532
# positive: 3.8096
# negative: 3.1448
# positive: 3.8848
# positive: 3.7612
# neutral: 4
# positive: 3.9548
# positive: 3.4076
# positive: 3.9568
# positive: 3.3084
# negative: 3.6248
# negative: 3.8068
# negative: 3.564
# neutral: 4
# neutral: 4
# neutral: 4
# positive: 3.3264
# negative: 2.9404
# positive: 3.954
# positive: 3.7728
# negative: 3.6168
# negative: 3.344
# neutral: 4
# negative: 3.6324
# neutral: 4
# negative: 3.6088
# negative: 3.7096
# neutral: 4
# negative: 3.422
# positive: 3.9264
# negative: 2.1692
# neutral: 4
# negative: 2.8012
# negative: 3.138
# positive: 3.8036
# neutral: 4
# neutral: 4
# negative: 2.5476
# positive: 3.9116
# positive: 3.8744
# neutral: 4
# positive: 3.4632
# positive: 2.2296
# positive: 3.8696
# positive: 3.7348
# positive: 3.564
# positive: 3.744
# positive: 3.7348
# positive: 3.2704
# positive: 2.1068
# negative: 3.5828
# positive: 3.0316
# neutral: 4
# positive: 3.7804
# positive: 3.06
# neutral: 4
# neutral: 4
# positive: 3.7612
# positive: 3.4076
# positive: 3.894
# neutral: 4
# positive: 2.9076
# negative: 3.1132
# negative: 3.1132
# negative: 3.7768
# negative: 3.744
# negative: 3.9248
# positive: 3.6168
# negative: 3.4632
# positive: 3.488
# positive: 3.3264
# neutral: 4
# negative: 3.5228
# negative: 3.794
# negative: 3.7396
# positive: 3.3768
# negative: 3.9024
# negative: 2.534
# negative: 3.9344
# negative: 3.838
# neutral: 4
# negative: 2.4496
# positive: 3.4076
# negative: 3.544
# positive: 3.3608
# negative: 3.6612
# negative: 2.1692
# neutral: 4
# positive: 3.6976
# negative: 3.0316
# negative: 2.5944
# neutral: 4
# positive: 3.5828
# positive: 3.8792
# negative: 3.638
# neutral: 4
# positive: 3.9104
# negative: 3.8208
# positive: 2.682
# negative: 2.9076
# neutral: 4
# negative: 2.9076
# neutral: 4
# positive: 2.2296
# negative: 3.7872
# neutral: 4
# positive: 3.3768
# negative: 2.3436
# neutral: 4
# negative: 3.6544
# positive: 3.5916
# positive: 3.0024
# positive: 2.8736
# positive: 3.7804
# neutral: 4
# negative: 3.8916
# positive: 3.1624
# neutral: 4
# positive: 2.8012
# positive: 2.2296
# positive: 3.8492
# negative: 3.7652
# neutral: 4
# neutral: 4
# positive: 3.574
# negative: 2.9404
# positive: 3.6984
# negative: 3.3264
# neutral: 4
# negative: 2.4496
# neutral: 4
# negative: 2.7232
# positive: 2.1068
# neutral: 4
# positive: 3.6612
# positive: 3.4364
# negative: 3.8492
# positive: 3.8312
# negative: 3.744
# positive: 3.0812
# negative: 3.8664
# neutral: 4
# positive: 2.9588
# neutral: 4
# negative: 3.0868
# negative: 3.6324
# negative: 2.0424
# negative: 3.8024
# negative: 3.208
# positive: 3.8592
# neutral: 4
# negative: 3.488
# negative: 2.2296
# negative: 2.934
# positive: 3.0868
# neutral: 4
# positive: 3.0868
# positive: 3.138
# positive: 3.4632
# positive: 3.924
# neutral: 4
# negative: 3.5228
# positive: 3.5916
# neutral: 4
# negative: 3.794
# negative: 2.2296
# positive: 3.882
# negative: 3.6544
# positive: 3.5336
# negative: 3.6088
# positive: 3.0024
# negative: 2.8532
# negative: 2.2876
# negative: 3.9292
# positive: 3.8664
# neutral: 4
# negative: 3.4076
# positive: 2.8736
# positive: 2.7184
# positive: 3.6016
# positive: 3.8988
# positive: 3.8776
# negative: 3.2704
# positive: 3.29
# positive: 3.8696
# positive: 3.5736
# negative: 3.836
# negative: 2.3436
# neutral: 4
# negative: 3.948
# negative: 3.564
# negative: 3.2704
# positive: 3.5828
# positive: 2.7632
# positive: 3.6088
# neutral: 4
# negative: 3.7804
# negative: 3.784
# positive: 3.564
# negative: 3.488
# negative: 3.704
# negative: 2.972
# positive: 2.0424
# neutral: 4
# positive: 3.8004
# negative: 3.7528
# negative: 3.8208
# positive: 3.5916
# negative: 2.972
# negative: 3.8152
# negative: 3.1132
# positive: 3.6248
# negative: 2.5944
# negative: 3.2504
# neutral: 4
# neutral: 4
# positive: 3.45
# negative: 3.45
# negative: 3.06
# neutral: 4
# negative: 2.8736
# neutral: 4
# neutral: 4
# neutral: 4
# positive: 2.4996
# negative: 3.5404
# negative: 3.5828
# positive: 3.0024
# positive: 3.6612
# negative: 3.704
# neutral: 4
# positive: 3.1624
# neutral: 4
# negative: 2.2876
# positive: 2.2876
# neutral: 4
# negative: 3.344
# neutral: 4
# neutral: 4
# neutral: 4
# negative: 2.5944
# negative: 3.5356
# neutral: 4
# negative: 2.3976
# negative: 3.564
# positive: 3.564
# negative: 3.7348
# negative: 3.6472
# negative: 3.344
# negative: 3.8592
# positive: 2.6388
# neutral: 4
# negative: 2.8736
# negative: 2.92
# negative: 3.06
# positive: 2.7232
# neutral: 4
# negative: 3.1624
# positive: 3.7484
# neutral: 4
# positive: 3.784
# positive: 2.2876
# positive: 3.0024
# negative: 3.0316
# neutral: 4
# negative: 3.8208
# negative: 3.6868
# neutral: 4
# negative: 3.7348
# positive: 3.2504
# neutral: 4
# negative: 2.6388
# negative: 3.4364
# positive: 3.3924
# positive: 3.8608
# positive: 3.4076
# negative: 3.8532
# negative: 3.6612
# neutral: 4
# negative: 2.9372
# neutral: 4
# neutral: 4
# neutral: 4
# positive: 3.344
# positive: 3.3084
# negative: 3.208
# negative: 2.8156
# negative: 3.7768
# neutral: 4
# negative: 3.5116
# negative: 3.7252
# positive: 3.8864
# negative: 3.45
# neutral: 4
# negative: 3.1856
# neutral: 4
# negative: 3.8928
# neutral: 4
# negative: 2.8012
# neutral: 4
# negative: 3.6804
# neutral: 4
# negative: 2.7632
# negative: 2.9404
# negative: 3.8068
# negative: 2.8012
# neutral: 4
# negative: 3.8892
# neutral: 4
# negative: 3.564
# positive: 3.5532
# neutral: 4
# positive: 2.5944
# positive: 3.5916
# negative: 3.4632
# negative: 3.1132
# neutral: 4
# positive: 2.5476
# neutral: 4
# negative: 3.1624
# negative: 3.0024
# negative: 2.2876
# positive: 3.138
# negative: 2.1068
# positive: 3.6324
# neutral: 4
# negative: 3.9
# negative: 3.422
# negative: 3.7612
# neutral: 4
# negative: 2.1692
# negative: 2.1068
# negative: 3.1132
# neutral: 4
# negative: 3.2704
# positive: 3.6004
# positive: 2.9076
# negative: 2.9076
# negative: 3.704
# positive: 2.8384
# neutral: 4
# negative: 2.0836
# negative: 3.4756
# negative: 2.4496
# positive: 2.3976
# negative: 2.8012
# negative: 3.7528
# negative: 3.3688
# positive: 3.8864
# positive: 2.8384
# positive: 2.0312
# negative: 3.91
# negative: 3.818
# negative: 3.06
# negative: 3.5828
# negative: 3.5828
# positive: 3.838
# negative: 3.8808
# negative: 3.8068
# neutral: 4
# positive: 3.138
# negative: 3.2504
# negative: 3.7252
# positive: 3.1856
# neutral: 4
# negative: 3.0024
# neutral: 4
# negative: 3.5228
# positive: 2.5944
# negative: 2.8736
# neutral: 4
# negative: 2.5032
# negative: 3.2116
# neutral: 4
# negative: 2.0424
# negative: 3.6868
# negative: 3.6868
# neutral: 4
# negative: 3.0868
# negative: 2.8384
# negative: 3.4756
# neutral: 4
# positive: 2.8756
# negative: 3.5336
# negative: 2.3436
# negative: 3.29
# negative: 3.636
# negative: 2.5944
# negative: 3.8068
# negative: 3.7484
# negative: 3.64
# negative: 3.45
# negative: 3.3608
# negative: 3.784
# negative: 3.4756
# negative: 3.8036
# negative: 2.3436
# negative: 3.9024
# negative: 3.06
# negative: 2.3436
# positive: 3.7252
# neutral: 4
# neutral: 4
# positive: 2.866
# positive: 2.682
# positive: 2.9076
# negative: 3.7692
# positive: 2.8616
# negative: 3.564
# negative: 3.7484
# positive: 3.29
# negative: 3.9096
# neutral: 4
# negative: 3.9204
# positive: 3.1132
# negative: 3.4756
# negative: 2.972
# neutral: 4
# positive: 3.6524
# negative: 3.6984
# negative: 2.5944
# negative: 3.876
# negative: 3.784
# negative: 3.554
# neutral: 4
# neutral: 4
# neutral: 4
# positive: 3.7484
# positive: 3.422
# neutral: 4
# negative: 3.7728
# positive: 3.8236
# neutral: 4
# negative: 2.8012
# neutral: 4
# negative: 2.8736
# neutral: 4
# neutral: 4
# negative: 3.7768
# negative: 3.7484
# neutral: 4
# positive: 3.208
# negative: 3.6612
# neutral: 4
# negative: 3.7692
# neutral: 4
# negative: 2.972
# positive: 2.5476
# negative: 3.73
# negative: 3.7768
# negative: 3.7148
# neutral: 4
# neutral: 4
# positive: 3.7312
# negative: 2.5944
# negative: 3.8492
# negative: 3.554
# negative: 2.7232
# neutral: 4
# neutral: 4
# negative: 3.1132
# positive: 2.5944
# negative: 3.7768
# negative: 3.4632
# negative: 3.3768
# negative: 2.6388
# negative: 3.138
# positive: 3.0336
# negative: 3.1132
# negative: 3.8004
# neutral: 4
# negative: 3.9332
# neutral: 4
# positive: 2.3976
# negative: 3.6744
# neutral: 4
# negative: 2.3436
# negative: 3.29
# negative: 3.8428
# positive: 2.7232
# positive: 2.972
# negative: 3.4364
# negative: 3.3924
# negative: 3.8592
# neutral: 4
# neutral: 4
# positive: 3.6472
# neutral: 4
# positive: 2.1068
# negative: 3.7768
# positive: 3.7348
# negative: 3.8608
# neutral: 4
# neutral: 4
# positive: 3.4076
# negative: 3.6676
# negative: 3.6612
# neutral: 4
# positive: 3.1132
# neutral: 4
# neutral: 4
# neutral: 4
# positive: 2.3976
# negative: 3.868
# positive: 2.1116
# neutral: 4
# negative: 3.8792
# neutral: 4
# negative: 3.0868
# negative: 3.7652
# negative: 3.488
# positive: 3.73
# negative: 3.4632
# negative: 3.7612
# negative: 3.64
# negative: 3.8492
# positive: 2.8012
# negative: 3.64
# negative: 2.7232
# negative: 3.6804
# positive: 3.7768
# positive: 3.544
# positive: 2.5476
# negative: 2.2296
# neutral: 4
# neutral: 4
# negative: 2.7232
# positive: 3.3608
# negative: 2.4496
# negative: 2.9404
# neutral: 4
# neutral: 4
# negative: 3.7612
# positive: 3.4932
# negative: 3.8428
# neutral: 4
# negative: 3.7616
# negative: 3.8696
# neutral: 4
# negative: 3.29
# negative: 2.5476
# negative: 2.0424
# neutral: 4
# positive: 3.9
# negative: 2.3436
# negative: 3.06
# positive: 2.972
# negative: 2.5944
# negative: 3.7024
# negative: 2.7632
# positive: 2.5476
# negative: 3.2704
# negative: 3.0024
# negative: 3.7908
# neutral: 4
# positive: 3.6984
# negative: 3.1132
# negative: 3.9264
# neutral: 4
# neutral: 4
# negative: 3.552
# negative: 3.8096
# positive: 3.45
# negative: 3.9076
# negative: 3.6544
# positive: 3.138
# neutral: 4
# negative: 3.488
# positive: 3.3084
# negative: 3.2296
# negative: 3.8876
# negative: 2.5476
# negative: 3.6868
# negative: 2.2876
# neutral: 4
# positive: 3.64
# negative: 3.6804
# neutral: 4
# positive: 3.5736
# positive: 2.7632
# negative: 3.658
# negative: 3.6324
# neutral: 4
# negative: 3.5
# negative: 3.6676
# neutral: 4
# negative: 3.8036
# neutral: 4
# negative: 2.682
# negative: 3.0868
# negative: 2.63
# negative: 3.2296
# negative: 2.1068
# negative: 2.588
# negative: 3.6544
# negative: 3.9176
# positive: 2.3976
# neutral: 4
# positive: 3.4632
# negative: 3.7728
# neutral: 4
# negative: 3.7728
# negative: 3.0316
# negative: 3.1132
# negative: 3.9104
# negative: 2.2876
# neutral: 4
# negative: 3.9312
# negative: 3.7804
# negative: 3.45
# negative: 3.6004
# negative: 2.5476
# positive: 3.6952
# neutral: 4
# negative: 3.564
# neutral: 4
# neutral: 4
# negative: 3.784
# negative: 3.6004
# positive: 3.6676
# negative: 3.7096
# negative: 3.6004
# negative: 2.7232
# neutral: 4
# negative: 2.8884
# negative: 2.8644
# negative: 2.9442000000000004
# negative: 2.0423999999999998
# positive: 2.733
# negative: 2.6654999999999998
# neutral: 3
# positive: 2.7603
# negative: 1.7982
# neutral: 3
# negative: 2.7003
# negative: 2.9082
# neutral: 3
# negative: 2.8695
# negative: 2.8785
# negative: 1.9457999999999998
# negative: 2.73
# negative: 2.5665
# positive: 2.5335
# negative: 2.4000000000000004
# negative: 2.6067
# neutral: 3
# negative: 2.6067
# negative: 2.6802
# negative: 2.7186
# negative: 1.7982
# negative: 2.7342
# positive: 2.2737
# negative: 2.7738
# positive: 1.5318
# negative: 2.778
# negative: 1.8747
# negative: 2.7756
# positive: 2.2053
# negative: 2.8353
# neutral: 3
# negative: 2.8236
# positive: 1.6269
# negative: 2.7975
# negative: 2.5773
# negative: 1.7526000000000002
# negative: 2.8773
# negative: 2.6067
# neutral: 3
# negative: 2.8869000000000002
# negative: 2.9157
# negative: 2.8712999999999997
# negative: 2.9034
# negative: 2.8851
# neutral: 3
# negative: 2.4675000000000002
# negative: 2.7186
# neutral: 3
# neutral: 3
# neutral: 3
# negative: 2.5557
# negative: 2.1552000000000002
# negative: 2.9022
# negative: 2.3349
# positive: 2.508
# negative: 2.6654999999999998
# neutral: 3
# negative: 2.406
# negative: 2.295
# negative: 2.6802
# neutral: 3
# negative: 2.2518000000000002
# negative: 2.8179
# negative: 2.8503
# neutral: 3
# neutral: 3
# negative: 2.5875000000000004
# negative: 2.8983
# negative: 2.1009
# negative: 2.8373999999999997
# negative: 2.8656
# negative: 2.8296
# negative: 1.9790999999999999
# negative: 2.1261
# negative: 2.8677
# neutral: 3
# negative: 2.9232
# negative: 2.508
# negative: 2.4222
# negative: 2.7066
# negative: 2.8914
# neutral: 3
# negative: 2.7405
# negative: 2.8269
# neutral: 3
# negative: 2.4378
# negative: 2.8239
# negative: 2.9148
# negative: 2.8011
# negative: 1.7576999999999998
# negative: 2.9328000000000003
# negative: 2.8146
# negative: 1.6722000000000001
# negative: 2.8656
# neutral: 3
# negative: 2.9424
# negative: 2.9415
# negative: 2.1807
# negative: 2.8572
# negative: 2.9349
# negative: 2.3535
# negative: 2.9046
# negative: 2.9259
# positive: 2.265
# negative: 1.9457999999999998
# negative: 2.8677
# negative: 2.7507
# negative: 2.943
# negative: 2.1288
# negative: 2.7603
# negative: 2.8074
# positive: 1.5423
# negative: 2.1807
# negative: 2.3535
# negative: 2.79
# negative: 2.2053
# neutral: 3
# negative: 1.5318
# negative: 2.8983
# neutral: 3
# negative: 2.3151
# negative: 2.658
# negative: 2.8677
# negative: 2.9268
# neutral: 3
# negative: 2.8752
# negative: 2.8853999999999997
# negative: 2.9382
# negative: 2.5206
# negative: 2.967
# neutral: 3
# negative: 2.388
# negative: 1.9457999999999998
# neutral: 3
# negative: 2.8404
# negative: 2.4528
# neutral: 3
# positive: 2.625
# negative: 2.7651
# negative: 2.8011
# negative: 2.9724
# negative: 2.7003
# neutral: 3
# negative: 2.295
# negative: 2.7003
# negative: 2.8146
# negative: 2.9115
# neutral: 3
# negative: 2.8613999999999997
# negative: 2.673
# negative: 2.8113
# negative: 2.8983
# negative: 2.9585999999999997
# negative: 2.3718
# negative: 2.2518000000000002
# positive: 1.7982
# negative: 2.6421
# negative: 2.6337
# negative: 2.8752
# negative: 2.9298
# negative: 2.8527
# negative: 1.9107
# negative: 2.0091
# negative: 2.508
# negative: 2.937
# negative: 1.8747
# neutral: 3
# positive: 2.7822
# negative: 2.2038
# neutral: 3
# negative: 2.406
# negative: 2.5875000000000004
# negative: 2.9268
# neutral: 3
# neutral: 3
# negative: 2.8296
# positive: 2.0724
# negative: 2.8803
# negative: 2.7651
# negative: 2.73
# negative: 2.6337
# negative: 2.8836000000000004
# negative: 2.658
# negative: 2.1807
# negative: 2.0502000000000002
# negative: 1.7576999999999998
# negative: 2.9375999999999998
# negative: 2.9733
# negative: 2.8239
# negative: 2.6421
# positive: 2.625
# negative: 2.9478
# negative: 2.925
# negative: 2.6658
# positive: 2.4906
# negative: 2.6421
# negative: 2.8695
# negative: 2.9046
# negative: 2.8479
# positive: 2.0423999999999998
# negative: 2.838
# negative: 2.9691
# negative: 2.2518000000000002
# negative: 2.3706
# negative: 2.1552000000000002
# neutral: 3
# negative: 2.7003
# negative: 2.925
# negative: 2.6502
# neutral: 3
# negative: 2.7003
# neutral: 3
# negative: 2.9223
# neutral: 3
# negative: 2.8179
# neutral: 3
# negative: 2.8239
# negative: 2.8853999999999997
# negative: 2.9619
# negative: 2.9148
# negative: 2.5326
# negative: 2.8998
# neutral: 3
# negative: 2.3718
# neutral: 3
# negative: 2.3535
# negative: 2.7066
# neutral: 3
# negative: 2.616
# neutral: 3
# negative: 2.9115
# negative: 2.6067
# neutral: 3
# negative: 2.8455
# negative: 2.5326
# negative: 2.0724
# negative: 2.9406
# neutral: 3
# negative: 2.9562
# positive: 2.5974
# negative: 2.8592999999999997
# negative: 2.937
# neutral: 3
# negative: 2.6502
# negative: 2.7657000000000003
# negative: 2.1288
# negative: 2.5206
# neutral: 3
# neutral: 3
# negative: 2.9558999999999997
# negative: 2.5557
# negative: 2.6871
# negative: 1.9434
# neutral: 3
# neutral: 3
# negative: 2.9664
# negative: 2.6067
# negative: 2.7123
# negative: 2.7408
# positive: 2.8605
# negative: 2.6421
# negative: 1.5318
# negative: 2.7003
# negative: 2.8853999999999997
# negative: 1.5800999999999998
# positive: 2.3891999999999998
# neutral: 3
# positive: 2.6802
# negative: 2.2518000000000002
# negative: 2.616
# negative: 2.9232
# negative: 2.6502
# neutral: 3
# neutral: 3
# positive: 1.7289
# negative: 2.8929
# negative: 2.6802
# negative: 2.8002000000000002
# positive: 1.6269
# negative: 2.2737
# neutral: 3
# neutral: 3
# neutral: 3
# neutral: 3
# neutral: 3
# negative: 2.8011
# negative: 1.5354
# neutral: 3
# positive: 1.9107
# negative: 2.9349
# positive: 1.7982
# neutral: 3
# negative: 2.8326000000000002
# negative: 2.8047
# negative: 2.8803
# positive: 2.1009
# negative: 2.8296
# neutral: 3
# negative: 2.229
# negative: 2.616
# negative: 2.9349
# neutral: 3
# negative: 2.964
# negative: 2.7651
# neutral: 3
# negative: 2.9127
# positive: 2.2053
# negative: 2.6871
# neutral: 3
# negative: 2.7693000000000003
# negative: 2.0724
# negative: 2.9409
# neutral: 3
# negative: 1.6722000000000001
# negative: 2.8952999999999998
# negative: 2.952
# negative: 2.1009
# negative: 2.7558
# neutral: 3
# neutral: 3
# neutral: 3
# positive: 2.4957
# negative: 1.7576999999999998
# negative: 2.8269
# neutral: 3
# negative: 2.4378
# neutral: 3
# neutral: 3
# positive: 2.3916
# positive: 1.7157
# negative: 2.8803
# negative: 2.7723
# negative: 2.5071
# negative: 2.625
# neutral: 3
# neutral: 3
# positive: 2.4528
# negative: 2.3151
# positive: 2.6802
# negative: 2.0423999999999998
# negative: 2.6421
# negative: 2.7066
# neutral: 3
# positive: 2.9082
# neutral: 3
# negative: 2.8836000000000004
# positive: 2.0724
# positive: 2.2053
# negative: 2.9093999999999998
# neutral: 3
# negative: 2.5773
# negative: 2.8179
# negative: 2.6421
# negative: 2.4675000000000002
# negative: 2.7861
# negative: 1.5318
# neutral: 3
# negative: 2.4366000000000003
# negative: 2.8011
# positive: 1.7277
# positive: 2.109
# negative: 2.7603
# negative: 1.7982
# negative: 2.8080000000000003
# negative: 2.8785
# negative: 2.877
# positive: 2.7873
# negative: 2.7140999999999997
# positive: 2.8836000000000004
# neutral: 3
# positive: 1.7576999999999998
# neutral: 3
# negative: 2.7939
# neutral: 3
# positive: 2.5326
# negative: 2.6034
# neutral: 3
# neutral: 3
# negative: 2.6421
# negative: 2.6871
# negative: 2.8998
# neutral: 3
# positive: 1.7157
# negative: 2.508
# neutral: 3
# neutral: 3
# neutral: 3
# negative: 2.4222
# neutral: 3
# positive: 2.616
# neutral: 3
# neutral: 3
# negative: 2.0724
# negative: 2.508
# positive: 2.9409
# negative: 1.5800999999999998
# negative: 2.1009
# negative: 2.7243
# negative: 2.3718
# negative: 2.406
# negative: 2.5326
# neutral: 3
# negative: 2.5557
# neutral: 3
# negative: 2.406
# negative: 2.406
# negative: 2.4813
# negative: 2.9178
# neutral: 3
# neutral: 3
# neutral: 3
# negative: 2.4222
# negative: 2.3891999999999998
# neutral: 3
# positive: 1.6269
# neutral: 3
# negative: 2.9127
# negative: 2.7243
# neutral: 3
# negative: 2.3196
# positive: 1.5975
# neutral: 3
# positive: 1.9790999999999999
# negative: 2.673
# negative: 2.295
# neutral: 3
# neutral: 3
# negative: 2.8503
# negative: 1.5354
# neutral: 3
# neutral: 3
# negative: 2.0724
# negative: 2.295
# negative: 2.6337
# negative: 2.8011
# neutral: 3
# negative: 2.0115
# neutral: 3
# negative: 1.818
# negative: 2.8853999999999997
# positive: 1.9107
# neutral: 3
# positive: 2.8080000000000003
# neutral: 3
# negative: 1.8747
# negative: 2.0115
# neutral: 3
# neutral: 3
# neutral: 3
# negative: 2.9259
# negative: 2.8677
# positive: 2.7975
# negative: 2.9487
# positive: 1.5318
# positive: 2.7126
# negative: 2.2518000000000002
# negative: 2.901
# positive: 2.901
# negative: 1.5318
# negative: 2.9358
# negative: 2.3223000000000003
# neutral: 3
# negative: 2.6421
# negative: 2.7126
# neutral: 3
# neutral: 3
# negative: 2.0994
# neutral: 3
# negative: 1.6206
# negative: 2.6646
# negative: 2.8404
# positive: 1.9790999999999999
# negative: 2.6337
# negative: 1.8456
# neutral: 3
# neutral: 3
# neutral: 3
# positive: 2.1552000000000002
# positive: 2.8209
# negative: 2.6724
# positive: 2.8209
# negative: 2.8719
# negative: 2.8983
# negative: 2.5773
# positive: 2.6802
# negative: 2.5302000000000002
# negative: 2.0745
# negative: 2.508
# negative: 2.9724
# negative: 2.9754
# negative: 2.3535
# positive: 2.9097
# positive: 2.4675000000000002
# negative: 1.7157
# negative: 1.7982
# negative: 2.6502
# positive: 2.7243
# positive: 2.4528
# negative: 2.9706
# negative: 2.9652
# positive: 1.9790999999999999
# negative: 2.9276999999999997
# negative: 2.9093999999999998
# positive: 2.9148
# positive: 2.6871
# positive: 2.1552000000000002
# negative: 2.73
# negative: 2.7459
# negative: 2.1009
# negative: 2.6502
# positive: 2.5437
# negative: 2.2053
# negative: 1.5800999999999998
# negative: 2.8011
# negative: 2.8983
# positive: 2.4555
# positive: 2.229
# positive: 2.229
# negative: 2.9349
# neutral: 3
# positive: 2.4675000000000002
# positive: 2.7861
# negative: 2.2053
# positive: 2.6061
# negative: 2.9457
# negative: 2.8296
# neutral: 3
# neutral: 3
# negative: 2.6555999999999997
# negative: 2.8113
# neutral: 3
# negative: 2.4813
# negative: 1.8372000000000002
# negative: 2.4222
# negative: 2.0724
# neutral: 3
# positive: 2.7003
# negative: 2.4528
# positive: 2.3349
# negative: 2.9058
# neutral: 3
# neutral: 3
# negative: 2.7354000000000003
# negative: 2.625
# positive: 2.7651
# negative: 1.7576999999999998
# positive: 2.3361
# negative: 1.9044
# negative: 2.8677
# positive: 2.3630999999999998
# negative: 2.616
# neutral: 3
# negative: 2.4222
# positive: 2.1288
# negative: 2.4813
# neutral: 3
# negative: 2.4783
# neutral: 3
# positive: 2.5557
# positive: 1.6269
# negative: 1.8747
# negative: 2.8056
# negative: 2.7354000000000003
# negative: 2.9196
# negative: 1.9457999999999998
# positive: 2.295
# positive: 2.1363
# positive: 2.4948
# neutral: 3
# neutral: 3
# negative: 2.6802
# positive: 1.7982
# neutral: 3
# negative: 1.5800999999999998
# negative: 2.6421
# negative: 2.8956
# negative: 2.3349
# negative: 2.6421
# negative: 2.2737
# positive: 2.9105999999999996
# negative: 2.8362
# negative: 2.7738
# negative: 2.7975
# negative: 2.9646
# negative: 2.9604
# positive: 2.7906
# negative: 2.295
# negative: 2.6654999999999998
# negative: 2.3718
# negative: 2.5326
# neutral: 3
# neutral: 3
# neutral: 3
# negative: 2.3754
# negative: 2.4528
# neutral: 3
# negative: 2.673
# neutral: 3
# positive: 2.8326000000000002
# positive: 2.1288
# positive: 1.9457999999999998
# negative: 2.838
# negative: 2.8269
# negative: 2.0724
# neutral: 3
# negative: 2.8677
# positive: 2.7126
# negative: 2.7558
# negative: 2.0991
# negative: 2.7126
# negative: 2.1009
# negative: 2.1552000000000002
# negative: 2.8572
# positive: 2.8785
# negative: 2.7126
# positive: 2.7126
# positive: 2.8656
# negative: 2.6067
# positive: 1.5318
# neutral: 3
# positive: 2.7126
# neutral: 3
# positive: 2.673
# neutral: 3
# negative: 2.7603
# positive: 1.6269
# positive: 2.7066
# positive: 2.0423999999999998
# neutral: 3
# positive: 2.2053
# neutral: 3
# positive: 2.5206
# positive: 2.6654999999999998
# negative: 2.8239
# positive: 1.5318
# neutral: 3
# positive: 2.8455
# negative: 1.9107
# positive: 1.6269
# negative: 2.8479
# negative: 1.7982
# neutral: 3
# negative: 2.1807
# negative: 1.7982
# negative: 1.8747
# neutral: 3
# neutral: 3
# negative: 2.8011
# negative: 2.7552
# neutral: 3
# negative: 2.8047
# positive: 2.1288
# positive: 2.3151
# negative: 2.0115
# positive: 1.7157
# positive: 2.0423999999999998
# neutral: 3
# positive: 2.229
# positive: 2.7738
# negative: 2.0724
# neutral: 3
# neutral: 3
# neutral: 3
# negative: 2.2182
# neutral: 3
# negative: 2.8269
# negative: 2.7573
# negative: 2.8239
# neutral: 3
# negative: 2.1009
# negative: 2.3151
# positive: 2.5326
# negative: 1.7576999999999998
# negative: 1.9790999999999999
# positive: 1.9107
# negative: 2.6931000000000003
# negative: 2.3718
# positive: 2.5206
# negative: 1.6269
# neutral: 3
# negative: 2.9223
# negative: 2.625
# positive: 2.4528
# positive: 2.6067
# negative: 2.295
# positive: 2.3535
# positive: 2.229
# positive: 2.3718
# positive: 2.7738
# neutral: 3
# negative: 2.7186
# positive: 2.877
# negative: 2.1009
# positive: 2.229
# neutral: 3
# neutral: 3
# neutral: 3
# positive: 1.9790999999999999
# positive: 2.1288
# negative: 2.0724
# positive: 2.4675000000000002
# negative: 2.0115
# negative: 2.2518000000000002
# negative: 2.7066
# negative: 2.4948
# positive: 1.6722000000000001
# positive: 1.6722000000000001
# neutral: 3
# negative: 2.8326000000000002
# positive: 2.5443
# negative: 2.7861
# negative: 2.9196
# neutral: 3
# negative: 2.871
# negative: 1.6269
# negative: 2.0423999999999998
# negative: 2.9127
# negative: 2.9142
# negative: 2.4813
# negative: 2.4813
# positive: 2.229
# negative: 2.5974
# neutral: 3
# negative: 2.0423999999999998
# positive: 2.8656
# positive: 2.8836000000000004
# negative: 2.7126
# negative: 2.5206
# positive: 1.6722000000000001
# negative: 1.6722000000000001
# positive: 2.0358
# negative: 2.9082
# neutral: 3
# neutral: 3
# positive: 2.1009
# positive: 2.616
# positive: 2.7975
# positive: 2.5557
# positive: 2.5773
# neutral: 3
# negative: 2.9283
# negative: 2.9604
# negative: 2.9402999999999997
# negative: 2.5773
# neutral: 3
# positive: 2.616
# negative: 2.937
# negative: 2.4528
# neutral: 3
# negative: 2.5443
# positive: 2.1288
# positive: 1.9790999999999999
# negative: 2.7675
# negative: 2.7558
# positive: 1.7982
# positive: 2.4813
# neutral: 3
# negative: 2.1807
# positive: 2.8080000000000003
# positive: 2.8047
# neutral: 3
# neutral: 3
# neutral: 3
# neutral: 3
# neutral: 3
# negative: 2.8314
# negative: 2.4675000000000002
# positive: 2.7507
# neutral: 3
# positive: 2.3349
# positive: 1.5800999999999998
# negative: 2.4222
# negative: 2.9241
# negative: 2.1009
# neutral: 3
# negative: 2.9558999999999997
# positive: 2.406
# negative: 2.7558
# neutral: 3
# positive: 2.616
# neutral: 3
# negative: 2.1288
# neutral: 3
# neutral: 3
# negative: 2.0724
# positive: 2.9337
# negative: 2.5974
# neutral: 3
# positive: 1.9457999999999998
# negative: 2.7693000000000003
# neutral: 3
# neutral: 3
# negative: 1.5800999999999998
# negative: 2.1807
# neutral: 3
# neutral: 3
# negative: 2.9595000000000002
# positive: 1.7925
# negative: 2.9616
# positive: 2.8944
# negative: 1.7982
# neutral: 3
# negative: 2.1288
# neutral: 3
# negative: 2.8853999999999997
# neutral: 3
# negative: 2.4222
# neutral: 3
# positive: 2.3151
# positive: 2.7024
# neutral: 3
# neutral: 3
# negative: 2.7465
# negative: 2.8430999999999997
# positive: 2.8011
# neutral: 3
# positive: 2.6823
# negative: 2.5335
# negative: 2.8884
# negative: 2.9562
# negative: 2.0423999999999998
# positive: 2.9058
# positive: 2.9337
# positive: 2.8635
# negative: 2.73
# positive: 2.7459
# neutral: 3
# negative: 1.8747
# negative: 2.1807
# neutral: 3
# positive: 2.5326
# negative: 2.6421
# positive: 2.7861
# negative: 2.9349
# positive: 2.406
# positive: 2.9472
# negative: 2.8551
# negative: 2.9214
# neutral: 3
# neutral: 3
# positive: 2.3151
# neutral: 3
# negative: 2.625
# negative: 2.673
# neutral: 3
# positive: 2.5875000000000004
# neutral: 3
# neutral: 3
# positive: 2.4623999999999997
# positive: 2.229
# positive: 2.8971
# negative: 2.9541
# negative: 2.3535
# neutral: 3
# negative: 2.7603
# negative: 2.295
# positive: 1.5318
# negative: 2.7408
# positive: 1.9790999999999999
# neutral: 3
# negative: 1.7868
# positive: 1.9107
# neutral: 3
# negative: 1.8372000000000002
# negative: 2.5206
# negative: 2.6856
# negative: 2.7507
# neutral: 3
# negative: 2.8712999999999997
# neutral: 3
# neutral: 3
# positive: 2.7651
# negative: 1.7157
# neutral: 3
# neutral: 3
# negative: 1.9457999999999998
# negative: 2.7243
# neutral: 3
# negative: 2.8080000000000003
# positive: 2.295
# negative: 2.8002000000000002
# neutral: 3
# neutral: 1
# neutral: 1
# positive: 0.743
# positive: 0.6124
# negative: 0.765
# negative: 0.8934
# neutral: 1
# negative: 0.8885
# positive: 0.6597
# neutral: 1
# positive: 0.5719
# positive: 0.6705
# negative: 0.8074
# positive: 0.9096
# positive: 0.6369
# neutral: 1
# negative: 0.8316
# negative: 0.8625
# negative: 0.9783
# negative: 0.5423
# neutral: 1
# negative: 0.8625
# negative: 0.9022
# neutral: 1
# negative: 0.5574
# negative: 0.8519
# negative: 0.9545
# negative: 0.6713
# neutral: 1
# neutral: 1
# negative: 0.9738
# negative: 0.8658
# neutral: 1
# neutral: 1
# neutral: 1
# negative: 0.9432
# neutral: 1
# neutral: 1
# positive: 0.6597
# neutral: 1
# negative: 0.9477
# negative: 0.9081
# negative: 0.6597
# neutral: 1
# neutral: 1
# negative: 0.8316
# positive: 0.807
# negative: 0.802
# negative: 0.875
# negative: 0.886
# neutral: 1
# positive: 0.8074
# positive: 0.9904
# negative: 0.7351
# neutral: 1
# neutral: 1
# negative: 0.5267
# neutral: 1
# neutral: 1
# neutral: 1
# neutral: 1
# neutral: 1
# neutral: 1
# negative: 0.9493
# positive: 0.6249
# negative: 0.5994
# neutral: 1
# negative: 0.9618
# negative: 0.9618
# positive: 0.5994
# negative: 0.9153
# negative: 0.8779
# negative: 0.8519
# neutral: 1
# negative: 0.9493
# negative: 0.8176
# negative: 0.8316
# neutral: 1
# negative: 0.8481
# positive: 0.5423
# neutral: 1
# negative: 0.7713
# positive: 0.6808
# neutral: 1
# positive: 0.6808
# neutral: 1
# positive: 0.7783
# neutral: 1
# positive: 0.6705
# positive: 0.8481
# neutral: 1
# neutral: 1
# neutral: 1
# positive: 0.6369
# negative: 0.9682
# negative: 0.8126
# neutral: 1
# negative: 0.6249
# neutral: 1
# negative: 0.7089
# negative: 0.6808
# neutral: 1
# positive: 0.6369
# neutral: 1
# neutral: 1
# negative: 0.9403
# neutral: 1
# negative: 0.886
# neutral: 1
# negative: 0.8957
# neutral: 1
# neutral: 1
# neutral: 1
# negative: 0.8316
# neutral: 1
# neutral: 1
# neutral: 1
# positive: 0.8074
# negative: 0.5574
# positive: 0.5994
# neutral: 1
# positive: 0.7783
# neutral: 1
# neutral: 1
# negative: 0.8442
# negative: 0.8442
# neutral: 1
# negative: 0.9517
# positive: 0.7184
# positive: 0.959
# negative: 0.5859
# positive: 0.9118
# positive: 0.8519
# neutral: 1
# positive: 0.8591
# neutral: 1
# neutral: 1
# negative: 0.8979
# neutral: 1
# neutral: 1
# negative: 0.7269
# negative: 0.8779
# negative: 0.9524
# neutral: 1
# neutral: 1
# neutral: 1
# neutral: 1
# ...
# negative: 2.925
# negative: 2.4948
# negative: 2.625
# negative: 2.8296
# negative: 2.5974
# negative: 2.8734
# positive: 2.3891999999999998
# positive: 2.8011
# positive: 2.6337
# neutral: 3
# negative: 2.877
# neutral: 3
# negative: 2.8836000000000004
# negative: 2.8146
# negative: 2.8179
# negative: 2.5875000000000004
# negative: 2.6654999999999998
# negative: 2.673
# negative: 2.4675000000000002
# negative: 2.9784
# positive: 2.7603
# negative: 1.8372000000000002
# negative: 1.6722000000000001
# negative: 2.4948
# negative: 2.4048
# neutral: 3
# negative: 2.9736
# negative: 2.6802
# negative: 2.406
# positive: 2.6471999999999998
# neutral: 3
# negative: 1.6722000000000001
# negative: 2.9388
# positive: 2.8239
# neutral: 3
# negative: 2.8764
# neutral: 3
# neutral: 3
# negative: 2.8353
# neutral: 3
# negative: 2.9064
# negative: 2.5206
# neutral: 3
# negative: 2.508
# negative: 2.9223
# negative: 2.9375999999999998
# negative: 2.508
# positive: 2.6103
# neutral: 3
# negative: 2.8146
# negative: 2.7558
# negative: 2.9276999999999997
# negative: 2.9022
# negative: 2.1942000000000004
# negative: 2.9538
# positive: 1.5800999999999998
# neutral: 3
# negative: 2.9127
# negative: 2.8592999999999997
# negative: 2.8587
# positive: 2.79
# negative: 2.7507
# negative: 2.877
# negative: 1.7576999999999998
# negative: 2.8218
# negative: 2.9508
# negative: 2.937
# negative: 2.5557
# negative: 2.2737
# negative: 2.79
# negative: 2.9448
# positive: 1.7982
# positive: 2.5875000000000004
# negative: 2.8677
# negative: 2.8011
# positive: 2.6724
# neutral: 3
# negative: 2.9415
# negative: 2.0724
# negative: 2.8803
# negative: 2.5326
# positive: 2.1807
# negative: 2.0115
# negative: 2.3718
# negative: 2.9798999999999998
# neutral: 3
# positive: 2.9241
# negative: 2.9034
# negative: 2.5557
# neutral: 3
# negative: 2.838
# negative: 2.8479
# negative: 2.4948
# negative: 2.5443
# negative: 2.8592999999999997
# positive: 2.8404
# negative: 2.9493
# negative: 1.8747
# neutral: 3
# negative: 2.8752
# negative: 2.9577
# negative: 2.658
# negative: 2.9148
# neutral: 3
# negative: 2.2053
# negative: 2.8269
# negative: 1.9107
# negative: 2.1807
# neutral: 3
# neutral: 3
# negative: 2.8929
# negative: 2.3151
# negative: 2.8911
# positive: 2.7186
# negative: 2.7897
# negative: 2.9676
# positive: 2.5206
# negative: 1.8456
# negative: 2.7243
# negative: 2.4675000000000002
# neutral: 3
# negative: 2.9751000000000003
# negative: 1.8747
# negative: 2.3349
# negative: 2.406
# positive: 2.5326
# negative: 2.1288
# negative: 2.1807
# negative: 2.8266
# positive: 2.295
# negative: 2.9214
# negative: 2.1807
# negative: 2.9169
# negative: 2.1009
# neutral: 3
# negative: 1.8747
# positive: 1.9790999999999999
# positive: 1.7982
# negative: 2.8146
# negative: 2.9649
# negative: 2.5665
# positive: 2.1624
# negative: 2.5665
# neutral: 3
# negative: 2.9484
# neutral: 3
# positive: 2.7003
# negative: 2.7186
# neutral: 3
# positive: 2.6997
# negative: 2.8269
# neutral: 3
# negative: 2.4675000000000002
# neutral: 3
# positive: 1.7576999999999998
# negative: 2.9364
# negative: 2.229
# negative: 2.0115
# negative: 2.3349
# negative: 1.8747
# neutral: 3
# negative: 2.9022
# neutral: 3
# negative: 2.3535
# negative: 1.6269
# negative: 2.6654999999999998
# neutral: 3
# negative: 2.8209
# negative: 2.9574
# negative: 2.2737
# negative: 2.673
# negative: 2.8821
# negative: 2.4222
# positive: 2.7651
# positive: 1.5318
# neutral: 3
# positive: 2.6654999999999998
# negative: 2.6802
# negative: 2.2737
# negative: 2.1807
# neutral: 3
# neutral: 3
# negative: 2.9709
# negative: 2.8956
# negative: 2.8011
# positive: 2.4378
# negative: 2.9082
# negative: 2.8656
# positive: 2.0535
# negative: 2.1288
# neutral: 3
# negative: 2.2737
# positive: 2.1288
# positive: 1.9457999999999998
# negative: 1.5318
# negative: 2.9642999999999997
# negative: 2.8998
# neutral: 3
# negative: 2.0724
# positive: 2.8047
# positive: 2.73
# negative: 2.8080000000000003
# neutral: 3
# negative: 2.8239
# negative: 2.6337
# negative: 2.9397
# neutral: 3
# negative: 2.8908
# neutral: 3
# negative: 2.4948
# neutral: 3
# neutral: 3
# negative: 2.7822
# negative: 2.7537000000000003
# positive: 2.4813
# negative: 2.517
# positive: 2.5665
# positive: 1.5800999999999998
# neutral: 3
# positive: 2.1807
# neutral: 3
# positive: 1.7982
# negative: 2.5326
# negative: 2.8131
# negative: 2.8853999999999997
# neutral: 3
# negative: 2.4948
# negative: 2.8113
# negative: 1.7576999999999998
# negative: 1.7982
# negative: 2.8635
# negative: 2.7651
# negative: 2.9868
# positive: 2.295
# neutral: 3
# negative: 2.9565
# neutral: 3
# negative: 2.8613999999999997
# negative: 1.8747
# negative: 1.5800999999999998
# negative: 2.2518000000000002
# negative: 2.8983
# negative: 2.2737
# neutral: 3
# positive: 1.5138000000000003
# negative: 2.9607
# negative: 2.9205
# negative: 2.9082
# neutral: 3
# positive: 2.5206
# negative: 2.7861
# positive: 1.6722000000000001
# negative: 1.7576999999999998
# neutral: 3
# neutral: 3
# neutral: 3
# positive: 2.8269
# neutral: 3
# positive: 2.1807
# negative: 2.8353
# negative: 2.778
# negative: 2.673
# negative: 2.1552000000000002
# negative: 2.3349
# neutral: 3
# neutral: 3
# positive: 2.2518000000000002
# positive: 2.9349
# negative: 2.7066
# negative: 2.4222
# positive: 2.0964
# negative: 1.7982
# neutral: 3
# positive: 1.6269
# positive: 2.6337
# positive: 2.8971
# positive: 2.8635
# negative: 2.8296
# positive: 2.6094
# negative: 2.8551
# positive: 2.7186
# neutral: 3
# negative: 2.673
# negative: 2.6205000000000003
# neutral: 3
# positive: 1.6722000000000001
# positive: 2.9544
# negative: 2.6421
# negative: 2.7822
# negative: 2.5884
# positive: 2.6937
# positive: 2.382
# neutral: 3
# negative: 2.1552000000000002
# positive: 2.4705
# positive: 2.3891999999999998
# negative: 1.7576999999999998
# negative: 2.7243
# positive: 2.3718
# negative: 1.7576999999999998
# negative: 2.7126
# positive: 2.8503
# negative: 2.9148
# positive: 2.5974
# neutral: 3
# negative: 2.9442000000000004
# positive: 2.9463
# negative: 2.6937
# neutral: 3
# neutral: 3
# negative: 1.5800999999999998
# negative: 2.7507
# negative: 2.3718
# neutral: 3
# negative: 2.9817
# negative: 2.9328000000000003
# negative: 2.2053
# negative: 2.7861
# negative: 2.8785
# negative: 2.8592999999999997
# negative: 1.9107
# negative: 2.7408
# positive: 2.7939
# negative: 1.8807
# positive: 2.1288
# neutral: 3
# positive: 1.5800999999999998
# neutral: 3
# neutral: 3
# neutral: 3
# positive: 2.5974
# negative: 2.5974
# neutral: 3
# neutral: 3
# positive: 2.3903999999999996
# negative: 2.5974
# positive: 2.5326
# negative: 1.9790999999999999
# neutral: 3
# negative: 2.406
# neutral: 3
# neutral: 3
# positive: 1.6269
# neutral: 3
# positive: 2.8677
# neutral: 3
# negative: 2.7603
# negative: 2.9157
# neutral: 3
# negative: 1.8747
# positive: 1.6722000000000001
# neutral: 3
# neutral: 3
# negative: 2.8881
# positive: 2.5326
# positive: 2.6145
# positive: 2.838
# neutral: 3
# positive: 2.5557
# negative: 2.4813
# negative: 2.8677
# positive: 2.7408
# neutral: 3
# neutral: 3
# positive: 2.1717
# negative: 1.7157
# negative: 2.9034
# neutral: 3
# negative: 2.8011
# negative: 2.9205
# positive: 2.7003
# neutral: 3
# positive: 1.6722000000000001
# negative: 2.6871
# negative: 2.5875000000000004
# negative: 2.1009
# positive: 1.7576999999999998
# negative: 2.5773
# positive: 2.6433
# neutral: 3
# negative: 2.8113
# negative: 2.508
# negative: 2.7939
# negative: 1.8747
# positive: 2.6937
# neutral: 3
# positive: 1.9107
# positive: 2.5557
# neutral: 3
# negative: 2.8146
# positive: 1.7157
# negative: 2.5533
# positive: 2.5773
# negative: 2.7087000000000003
# neutral: 3
# positive: 2.907
# negative: 2.6937
# neutral: 3
# neutral: 3
# positive: 1.9790999999999999
# negative: 2.1552000000000002
# positive: 2.5443
# negative: 2.616
# negative: 2.2053
# neutral: 3
# positive: 2.4528
# negative: 2.229
# negative: 2.6337
# negative: 2.9337
# neutral: 3
# positive: 1.7069999999999999
# positive: 2.0115
# neutral: 3
# neutral: 3
# negative: 2.9433
# negative: 2.8983
# neutral: 3
# positive: 2.0115
# negative: 2.778
# neutral: 3
# negative: 2.8353
# negative: 2.7603
# negative: 2.3361
# negative: 2.4222
# positive: 2.2737
# neutral: 3
# positive: 2.8080000000000003
# negative: 2.673
# negative: 2.5866
# negative: 2.778
# positive: 2.1009
# positive: 2.0423999999999998
# positive: 2.8899
# negative: 2.9528999999999996
# negative: 2.8572
# positive: 2.8853999999999997
# positive: 2.862
# negative: 2.8785
# negative: 2.7459
# negative: 2.8455
# positive: 2.7669
# negative: 2.4948
# positive: 2.2737
# negative: 2.8956
# neutral: 3
# negative: 2.7693000000000003
# neutral: 3
# positive: 2.0423999999999998
# positive: 2.5773
# negative: 2.4813
# negative: 2.406
# neutral: 3
# negative: 2.3952
# neutral: 3
# negative: 2.8656
# negative: 2.616
# negative: 2.9652
# negative: 2.9349
# negative: 2.9418
# neutral: 3
# negative: 2.8998
# positive: 2.1552000000000002
# negative: 2.9454000000000002
# neutral: 3
# positive: 1.9790999999999999
# negative: 2.838
# positive: 2.9127
# neutral: 3
# negative: 2.4378
# negative: 2.2518000000000002
# negative: 2.6937
# negative: 2.9703
# positive: 1.6749
# negative: 2.4813
# neutral: 3
# negative: 2.295
# neutral: 3
# negative: 1.9457999999999998
# negative: 2.6231999999999998
# negative: 2.5749
# neutral: 3
# negative: 2.7738
# negative: 2.9205
# neutral: 3
# negative: 2.1552000000000002
# negative: 2.2518000000000002
# neutral: 3
# negative: 1.9790999999999999
# positive: 2.9259
# positive: 2.8734
# negative: 2.8551
# neutral: 3
# negative: 2.625
# neutral: 3
# negative: 2.6898
# neutral: 3
# neutral: 3
# neutral: 3
# negative: 2.7459
# negative: 2.2053
# negative: 1.5800999999999998
# negative: 1.9790999999999999
# positive: 2.7459
# positive: 2.2518000000000002
# positive: 2.7939
# negative: 2.7975
# negative: 2.5557
# positive: 2.2737
# negative: 2.8734
# positive: 2.2584
# neutral: 3
# neutral: 3
# negative: 2.2053
# negative: 2.406
# positive: 2.8695
# negative: 2.6502
# neutral: 3
# negative: 2.8821
# neutral: 3
# positive: 1.7576999999999998
# negative: 2.0115
# negative: 2.3891999999999998
# negative: 2.4813
# negative: 2.5443
# negative: 2.4897
# negative: 2.6937
# negative: 2.925
# negative: 2.8059000000000003
# negative: 2.9214
# positive: 2.6921999999999997
# negative: 2.7507
# negative: 2.9388
# negative: 2.4528
# negative: 2.5974
# negative: 2.8592999999999997
# positive: 2.9187
# negative: 2.8869000000000002
# negative: 2.6421
# negative: 2.7066
# negative: 2.508
# negative: 2.8677
# positive: 1.9674
# positive: 2.9187
# negative: 2.6871
# negative: 2.7600000000000002
# neutral: 3
# neutral: 3
# negative: 2.4675000000000002
# negative: 2.7948
# negative: 2.9135999999999997
# positive: 2.5326
# negative: 2.0745
# negative: 2.7651
# negative: 2.9781
# negative: 2.9565
# positive: 2.7939
# negative: 2.6337
# negative: 2.79
# negative: 2.7507
# positive: 2.406
# neutral: 3
# negative: 2.9343
# positive: 2.5665
# positive: 2.6802
# neutral: 3
# negative: 1.6722000000000001
# positive: 2.1552000000000002
# neutral: 3
# negative: 2.508
# neutral: 3
# negative: 2.9268
# positive: 2.1552000000000002
# positive: 2.907
# negative: 2.8836000000000004
# neutral: 3
# negative: 2.6337
# positive: 2.8734
# neutral: 3
# neutral: 3
# neutral: 3
# negative: 2.2737
# negative: 2.2518000000000002
# negative: 2.5443
# negative: 2.778
# neutral: 3
# negative: 2.5326
# positive: 2.1807
# negative: 2.9064
# negative: 2.9484
# neutral: 3
# negative: 2.7693000000000003
# negative: 2.5665
# negative: 2.8476
# negative: 2.8836000000000004
# positive: 2.4528
# positive: 2.1807
# negative: 2.877
# negative: 2.8239
# neutral: 3
# negative: 2.8011
# negative: 2.9699999999999998
# neutral: 3
# positive: 2.0703
# negative: 2.406
# negative: 2.2518000000000002
# negative: 2.9688
# negative: 2.4675000000000002
# positive: 2.9178
# positive: 2.877
# negative: 2.9046
# negative: 1.5972
# positive: 2.4813
# neutral: 3
# neutral: 3
# negative: 2.5488
# neutral: 3
# neutral: 3
# negative: 2.6421
# neutral: 3
# negative: 2.1288
# negative: 1.9457999999999998
# negative: 2.6337
# neutral: 3
# positive: 2.3718
# positive: 2.4675000000000002
# negative: 2.8785
# positive: 2.3151
# negative: 2.8656
# negative: 2.8821
# negative: 2.9382
# negative: 2.4378
# negative: 2.2737
# negative: 2.8971
# negative: 2.8113
# negative: 1.7982
# negative: 2.9022
# neutral: 3
# positive: 2.2737
# negative: 2.9871
# negative: 2.8752
# negative: 2.7648
# positive: 2.8551
# neutral: 3
# negative: 2.9259
# positive: 2.007
# negative: 1.9457999999999998
# negative: 2.0703
# negative: 1.9457999999999998
# negative: 2.6802
# negative: 2.406
# negative: 2.0423999999999998
# negative: 2.8785
# negative: 2.8113
# negative: 2.9718
# negative: 2.8884
# negative: 2.7975
# negative: 2.9148
# positive: 2.8446000000000002
# negative: 2.8047
# negative: 2.9058
# negative: 2.9805
# negative: 2.9307
# negative: 2.7693000000000003
# neutral: 3
# positive: 2.3891999999999998
# neutral: 3
# negative: 2.9604
# positive: 2.1552000000000002
# neutral: 3
# negative: 2.7426
# negative: 1.9107
# neutral: 3
# negative: 2.9871
# negative: 2.3891999999999998
# neutral: 3
# negative: 2.8668
# negative: 2.7939
# negative: 2.877
# neutral: 3
# negative: 1.9457999999999998
# neutral: 3
# neutral: 3
# neutral: 3
# negative: 2.8353
# positive: 1.7982
# negative: 2.8836000000000004
# positive: 2.7507
# positive: 1.7982
# negative: 2.8011
# negative: 2.658
# positive: 1.9107
# neutral: 3
# negative: 2.9601
# negative: 2.79
# positive: 2.3151
# negative: 2.1009
# neutral: 3
# positive: 2.6691000000000003
# negative: 2.5665
# positive: 2.673
# negative: 2.5773
# negative: 2.8572
# negative: 2.4222
# negative: 2.9676
# positive: 2.8269
# positive: 2.9046
# neutral: 3
# negative: 2.9532000000000003
# negative: 2.7459
# neutral: 3
# neutral: 3
# neutral: 3
# negative: 2.8404
# negative: 2.9409
# positive: 1.5800999999999998
# positive: 1.7576999999999998
# negative: 2.8503
# negative: 2.4048
# positive: 2.616
# positive: 2.0115
# neutral: 3
# positive: 2.5443
# neutral: 3
# negative: 2.8656
# negative: 2.9343
# neutral: 3
# neutral: 3
# neutral: 3
# neutral: 3
# neutral: 3
# positive: 2.0724
# negative: 2.5326
# negative: 2.8080000000000003
# positive: 1.5800999999999998
# negative: 2.5773
# neutral: 3
# positive: 2.3535
# negative: 2.4222
# neutral: 3
# negative: 2.9214
# negative: 2.0423999999999998
# negative: 2.9457
# neutral: 3
# negative: 2.6937
# negative: 2.9268
# neutral: 3
# negative: 2.8956
# negative: 2.6871
# negative: 2.8899
# neutral: 3
# negative: 2.9484
# negative: 2.9484
# negative: 2.8011
# negative: 2.907
# negative: 2.8254
# negative: 2.8998
# negative: 2.2071
# negative: 2.8869000000000002
# negative: 2.7003
# negative: 2.9382
# negative: 2.5974
# negative: 1.6269
# negative: 2.3535
# positive: 2.4222
# negative: 1.6269
# positive: 2.3718
# negative: 2.5875000000000004
# negative: 2.925
# negative: 2.9358
# negative: 2.925
# negative: 2.9754
# negative: 2.2053
# negative: 2.6421
# positive: 1.9107
# neutral: 3
# neutral: 3
# positive: 1.5800999999999998
# neutral: 3
# positive: 2.8209
# neutral: 3
# positive: 2.4528
# negative: 2.8884
# neutral: 3
# neutral: 3
# neutral: 3
# positive: 2.4948
# positive: 1.5800999999999998
# neutral: 3
# negative: 2.6502
# negative: 2.9034
# negative: 2.3151
# negative: 2.3349
# negative: 2.8503
# negative: 2.9028
# neutral: 3
# negative: 1.9790999999999999
# positive: 2.508
# neutral: 3
# negative: 2.4813
# negative: 2.7603
# negative: 2.6337
# neutral: 3
# negative: 2.9595000000000002
# negative: 2.406
# negative: 2.616
# positive: 2.1807
# negative: 2.778
# negative: 2.8884
# negative: 2.8656
# negative: 2.625
# positive: 1.5800999999999998
# negative: 2.616
# positive: 2.295
# negative: 2.0423999999999998
# negative: 2.8209
# neutral: 3
# negative: 2.8803
# neutral: 3
# negative: 2.9859
# negative: 2.4813
# positive: 1.7982
# negative: 2.8047
# negative: 2.73
# positive: 2.3718
# positive: 1.5318
# negative: 2.8677
# negative: 2.7186
# positive: 2.0423999999999998
# neutral: 3
# negative: 2.8899
# positive: 2.1288
# positive: 2.229
# positive: 1.9593
# negative: 2.8998
# negative: 1.7982
# neutral: 3
# positive: 2.7507
# neutral: 3
# negative: 2.9382
# negative: 2.9115
# negative: 2.8998
# positive: 2.4623999999999997
# neutral: 3
# neutral: 3
# neutral: 3
# negative: 1.5800999999999998
# negative: 2.9676
# negative: 2.8752
# negative: 2.9283
# negative: 2.9676
# negative: 2.8353
# negative: 2.73
# neutral: 3
# positive: 1.8747
# negative: 2.8556999999999997
# negative: 2.907
# negative: 2.646
# neutral: 3
# neutral: 3
# positive: 2.4378
# negative: 2.1807
# negative: 2.901
# negative: 1.9107
# neutral: 3
# negative: 2.9313
# negative: 2.8956
# negative: 1.7157
# negative: 2.0115
# negative: 2.5974
# neutral: 3
# negative: 2.4378
# negative: 2.2737
# positive: 2.8692
# neutral: 3
# negative: 2.0724
# positive: 1.8747
# negative: 2.9105999999999996
# negative: 2.9082
# neutral: 3
# negative: 1.6722000000000001
# positive: 2.7126
# negative: 2.3718
# negative: 2.8269
# negative: 2.7738
# negative: 2.7603
# positive: 2.658
# negative: 2.7186
# negative: 2.9558999999999997
# negative: 2.8080000000000003
# negative: 2.8011
# neutral: 3
# negative: 2.8430999999999997
# neutral: 3
# negative: 2.0115
# neutral: 3
# negative: 2.7798
# negative: 2.8011
# positive: 2.7693000000000003
# positive: 2.7408
# neutral: 3
# negative: 2.9313
# neutral: 3
# negative: 2.3349
# negative: 2.6654999999999998
# positive: 2.1552000000000002
# negative: 2.7354000000000003
# negative: 2.9283
# positive: 1.6269
# negative: 1.5800999999999998
# neutral: 3
# negative: 2.3718
# negative: 2.6067
# negative: 1.8372000000000002
# negative: 2.8146
# negative: 2.7651

# %%
df.head()
# Out:
#      date                   location  \
# 0  Feb-22          MUMBAI (REUTERS)
# 1  Feb-22          ZURICH (REUTERS)
# 2  Feb-22          VIENNA (REUTERS)
# 3  Feb-22       NEW DELHI (REUTERS)
# 4  Feb-21  SALT LAKE CITY (NYTIMES)
#
#                                           news title  \
# 0  Himalayan avalanche kills seven Indian soldier...
# 1  Eight killed in two days after third deadly av...
# 2  Avalanche in Austria near Swiss border kills five
# 3  Himalayan avalanche traps Indian Army patrol t...
# 4  4 skiers killed in avalanche in Utah, official...
#
#                                     news source(url)  \
# 0  https://www.straitstimes.com/asia/himalayan-av...
# 1  https://www.straitstimes.com/world/europe/eigh...
# 2  https://www.straitstimes.com/world/europe/aval...
# 3  https://www.straitstimes.com/asia/south-asia/h...
# 4  https://www.straitstimes.com/world/united-stat...
#
#                                      content summary  \
# 0  MUMBAI (REUTERS) - A Himalayan avalanche kille...
# 1  ZURICH (REUTERS) - One person was killed and f...
# 2  VIENNA (REUTERS) - An avalanche in an area of ...
# 3  NEW DELHI (REUTERS) - A Himalayan avalanche tr...
# 4  SALT LAKE CITY (NYTIMES) - Four back-country s...
#
#                                             keywords          class_name  \
# 0  kills, avalanche, defence, kameng, china, sold...  natural calamities
# 1  person, avalanche, tyrol, killed, days, skiers...  natural calamities
# 2  kills, avalanche, person, services, supervisor...  natural calamities
# 3  arunachal, avalanche, army, defence, team, chi...  natural calamities
# 4  avalanche, states, killed, skiers, saidthe, sa...  natural calamities
#
#       new_class_name                                  Preprocessed_Text  \
# 0  geophysical event  ['mumbai', 'reuters', 'himalayan', 'avalanche'...
# 1  geophysical event  ['zurich', 'reuters', 'one', 'person', 'killed...
# 2  geophysical event  ['vienna', 'reuters', 'avalanche', 'area', 'au...
# 3  geophysical event  ['new', 'delhi', 'reuters', 'himalayan', 'aval...
# 4  geophysical event  ['salt', 'lake', 'city', 'nytimes', 'four', 'b...
#
#                                   Preprocessed_Text2  \
# 0  mumbai reuters himalayan avalanche killed seve...
# 1  zurich reuters one person killed four others i...
# 2  vienna reuters avalanche area austria borderin...
# 3  new delhi reuters himalayan avalanche trapped ...
# 4  salt lake city nytimes four back country skier...
#
#                                      sentiment score  compound score  \
# 0  {'neg': 0.148, 'neu': 0.773, 'pos': 0.079, 'co...         -0.7506
# 1  {'neg': 0.276, 'neu': 0.63, 'pos': 0.094, 'com...         -0.9665
# 2  {'neg': 0.258, 'neu': 0.607, 'pos': 0.135, 'co...         -0.9100
# 3  {'neg': 0.045, 'neu': 0.782, 'pos': 0.172, 'co...          0.8225
# 4  {'neg': 0.258, 'neu': 0.703, 'pos': 0.039, 'co...         -0.9509
#
#   sentiment label  Likelihood Score  Severity Score  Human Control Score  \
# 0        negative                 3               2                    1
# 1        negative                 3               2                    1
# 2        negative                 3               2                    1
# 3        positive                 3               2                    1
# 4        negative                 3               2                    1
#
#    New Severity Score
# 0              1.5012
# 1              1.9330
# 2              1.8200
# 3              1.6450
# 4              1.9018

# %% [markdown]
# # Reference Codes

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
from numpy.random import rand
from pylab import figure

 
m=rand(3,3) # m is an array of (x,y,z) coordinate triplets
 
fig = figure()
ax = fig.add_subplot(projection='3d')

for i in range(len(m)): #plot each point + it's index as text above
    ax.scatter(m[i,0],m[i,1],m[i,2],color='r') 
    ax.text(m[i,0],m[i,1],m[i,2],  '%s' % (str(i)), size=20, zorder=1,  
    color='k') 

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
pyplot.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
