# %% [markdown]
# # News Articles Categorisation
#
#
# The steps to build the model are
#
# - Data Exploration
# - Text Processing (Cleaning)
# - Feature Extraction
# - Modelling
# - Use the Model

# %% [markdown]
# # Possible Reference
#
#
# - https://www.analyticsvidhya.com/blog/2021/08/malawi-news-classification-an-nlp-project/

# %% [markdown]
# # Importing Libraries

# %%
import nltk

# nltk.download()

# %%
# Import libraries

import pandas as pd
import re 

import nltk 
from nltk.tokenize import RegexpTokenizer
from collections import Counter 
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost 
from sklearn.metrics  import classification_report
from sklearn import metrics
import time

# %% [markdown]
# # Combining multiple excel files into one dataframe

# %%
import os
import pandas as pd
cwd = os.path.abspath('CSV data') 
files = os.listdir(cwd)

# %%
cwd
# Out:
# 'C:\\Users\\Darren\\Documents\\GitHub\\FSX\\News Categorisation\\CSV data'

# %%
files
# Out:
# ['avalanche_straitstimes.csv',
#  'dengue_straitstimes.csv',
#  'pandemic_straitstimes.csv',
#  'volcanic eruption_straitstimes.csv']

# %%
df = pd.DataFrame()
for file in files:
     if file.endswith('.csv'):
         df = df.append(pd.read_csv(file), ignore_index=True) 
df.head()
# Out:
#    Unnamed: 0     date                   location  \
# 0           0  02/2022          MUMBAI (REUTERS)
# 1           1  02/2022          ZURICH (REUTERS)
# 2           2  02/2022          VIENNA (REUTERS)
# 3           3  02/2022       NEW DELHI (REUTERS)
# 4           4  02/2021  SALT LAKE CITY (NYTIMES)
#
#                                           news title  \
# 0  Himalayan avalanche kills seven Indian soldier...
# 1  Eight killed in two days after third deadly av...
# 2  Avalanche in Austria near Swiss border kills five
# 3  Himalayan avalanche traps Indian Army patrol t...
# 4  4 skiers killed in avalanche in Utah, official...
#
#                                     news source(url)  \
# 0  https://www.straitstimes.com/asia/himalayan-av...
# 1  https://www.straitstimes.com/world/europe/eigh...
# 2  https://www.straitstimes.com/world/europe/aval...
# 3  https://www.straitstimes.com/asia/south-asia/h...
# 4  https://www.straitstimes.com/world/united-stat...
#
#                                      content summary  \
# 0  MUMBAI (REUTERS) - A Himalayan avalanche kille...
# 1  ZURICH (REUTERS) - One person was killed and f...
# 2  VIENNA (REUTERS) - An avalanche in an area of ...
# 3  NEW DELHI (REUTERS) - A Himalayan avalanche tr...
# 4  SALT LAKE CITY (NYTIMES) - Four back-country s...
#
#                                             keywords          class_name
# 0  kills, avalanche, defence, kameng, china, sold...  natural calamities
# 1  person, avalanche, tyrol, killed, days, skiers...  natural calamities
# 2  kills, avalanche, person, services, supervisor...  natural calamities
# 3  arunachal, avalanche, army, defence, team, chi...  natural calamities
# 4  avalanche, states, killed, skiers, saidthe, sa...  natural calamities

# %%
df.shape
# Out:
# (1316, 8)

# %%
df['class_name'].value_counts()
# Out:
# natural calamities     776
# Human health crises    540
# Name: class_name, dtype: int64

# %% [markdown]
# # Data Exploration

# %%
category = list(df['class_name'].unique())
category
# Out:
# ['natural calamities', 'Human health crises']

# %% [markdown]
# # Text Preprocessing

# %%
def preprocess(text):
    
    """
    Function: split text into words and return the root form of the words
    Args:
      text(str): the article
    Return:
      lem(list of str): a list of the root form of the article words
    """
        
    # Normalize text
    text = re.sub(r"[^a-zA-Z]", " ", str(text).lower())
    
    # Tokenize text
    token = word_tokenize(text)
    
    # Remove stop words
    stop = stopwords.words("english")
    words = [t for t in token if t not in stop]
    
    # Lemmatization
    lem = [WordNetLemmatizer().lemmatize(w) for w in words]
    
    return lem

# %%
df["Preprocessed_Text"] = df['content summary'].apply(lambda x: preprocess(x))
df.head(10)
# Out:
#    Unnamed: 0     date                           location  \
# 0           0  02/2022                  MUMBAI (REUTERS)
# 1           1  02/2022                  ZURICH (REUTERS)
# 2           2  02/2022                  VIENNA (REUTERS)
# 3           3  02/2022               NEW DELHI (REUTERS)
# 4           4  02/2021          SALT LAKE CITY (NYTIMES)
# 5           5  04/2021                NEW DELHI (XINHUA)
# 6           6  01/2021                  VIENNA (REUTERS)
# 7           7  01/2021                      FRANCE (AFP)
# 8           8  01/2020  MUZAFFARABAD, PAKISTAN (REUTERS)
# 9           9  12/2019                  VIENNA (REUTERS)
#
#                                           news title  \
# 0  Himalayan avalanche kills seven Indian soldier...
# 1  Eight killed in two days after third deadly av...
# 2  Avalanche in Austria near Swiss border kills five
# 3  Himalayan avalanche traps Indian Army patrol t...
# 4  4 skiers killed in avalanche in Utah, official...
# 5  8 killed after glacial burst triggers avalanch...
# 6  Dogs' barking prompts owners' rescue from Swis...
# 7  'Miracle' escape for man trapped in Alps avala...
# 8  Girl buried under Pakistan avalanche for 18 ho...
# 9  Rescuers comb Austrian, Swiss avalanches in ca...
#
#                                     news source(url)  \
# 0  https://www.straitstimes.com/asia/himalayan-av...
# 1  https://www.straitstimes.com/world/europe/eigh...
# 2  https://www.straitstimes.com/world/europe/aval...
# 3  https://www.straitstimes.com/asia/south-asia/h...
# 4  https://www.straitstimes.com/world/united-stat...
# 5  https://www.straitstimes.com/asia/south-asia/8...
# 6  https://www.straitstimes.com/world/europe/dogs...
# 7  https://www.straitstimes.com/world/europe/mira...
# 8  https://www.straitstimes.com/asia/south-asia/g...
# 9  https://www.straitstimes.com/world/europe/resc...
#
#                                      content summary  \
# 0  MUMBAI (REUTERS) - A Himalayan avalanche kille...
# 1  ZURICH (REUTERS) - One person was killed and f...
# 2  VIENNA (REUTERS) - An avalanche in an area of ...
# 3  NEW DELHI (REUTERS) - A Himalayan avalanche tr...
# 4  SALT LAKE CITY (NYTIMES) - Four back-country s...
# 5  According to officials, 384 others, mostly bel...
# 6  VIENNA (REUTERS) - Two people caught in an ava...
# 7  FRANCE (AFP) - A man out walking with his fami...
# 8  MUZAFFARABAD, PAKISTAN (REUTERS) - A 12-year-o...
# 9  VIENNA (REUTERS) - Rescuers hunted for possibl...
#
#                                             keywords          class_name  \
# 0  kills, avalanche, defence, kameng, china, sold...  natural calamities
# 1  person, avalanche, tyrol, killed, days, skiers...  natural calamities
# 2  kills, avalanche, person, services, supervisor...  natural calamities
# 3  arunachal, avalanche, army, defence, team, chi...  natural calamities
# 4  avalanche, states, killed, skiers, saidthe, sa...  natural calamities
# 5  avalanche, officials, bro, glacial, uttarakhan...  natural calamities
# 6  dogs, avalanche, buried, snowshoers, group, wi...  natural calamities
# 7  minutes, avalanche, local, escape, snow, rescu...  natural calamities
# 8  buried, avalanche, waited, pakistan, village, ...  natural calamities
# 9  avalanche, large, snow, warning, swiss, victim...  natural calamities
#
#                                    Preprocessed_Text
# 0  [mumbai, reuters, himalayan, avalanche, killed...
# 1  [zurich, reuters, one, person, killed, four, o...
# 2  [vienna, reuters, avalanche, area, austria, bo...
# 3  [new, delhi, reuters, himalayan, avalanche, tr...
# 4  [salt, lake, city, nytimes, four, back, countr...
# 5  [according, official, others, mostly, belongin...
# 6  [vienna, reuters, two, people, caught, avalanc...
# 7  [france, afp, man, walking, family, french, al...
# 8  [muzaffarabad, pakistan, reuters, year, old, g...
# 9  [vienna, reuters, rescuer, hunted, possible, v...

# %% [markdown]
# # Text Exploration

# %%
def find_common_words(df, category):
        
    """
    Function: find the most frequent words in the category and return the them
    Args:
      df(dataframe): the dataframe of articles
      category(str): the category name
    Return:
      the most frequant words in the category
    """
        
    # Create dataframes for the category
    cat_df = df[df["class_name"]==category]
    
    # Initialize words list for the category
    words = [word for tokens in cat_df["Preprocessed_Text"] for word in tokens]
    
    # Count words frequency
    words_counter = Counter(words)
 
    return words_counter.most_common(10)

# %%
print("Most common words in each category")
for c in category:
    print(c, " News")
    print(find_common_words(df, c))
    print()
# Out:
# Most common words in each category
# natural calamities  News
# [('said', 904), ('volcano', 554), ('eruption', 423), ('people', 397), ('avalanche', 308), ('mr', 300), ('year', 269), ('new', 265), ('island', 248), ('ash', 231)]
#
# Human health crises  News
# [('dengue', 955), ('year', 578), ('case', 515), ('said', 456), ('singapore', 381), ('mosquito', 353), ('pandemic', 315), ('number', 261), ('last', 259), ('covid', 238)]

# %%
df['Preprocessed_Text2'] = df['Preprocessed_Text'].apply(' '.join)
df.head()
# Out:
#    Unnamed: 0     date                   location  \
# 0           0  02/2022          MUMBAI (REUTERS)
# 1           1  02/2022          ZURICH (REUTERS)
# 2           2  02/2022          VIENNA (REUTERS)
# 3           3  02/2022       NEW DELHI (REUTERS)
# 4           4  02/2021  SALT LAKE CITY (NYTIMES)
#
#                                           news title  \
# 0  Himalayan avalanche kills seven Indian soldier...
# 1  Eight killed in two days after third deadly av...
# 2  Avalanche in Austria near Swiss border kills five
# 3  Himalayan avalanche traps Indian Army patrol t...
# 4  4 skiers killed in avalanche in Utah, official...
#
#                                     news source(url)  \
# 0  https://www.straitstimes.com/asia/himalayan-av...
# 1  https://www.straitstimes.com/world/europe/eigh...
# 2  https://www.straitstimes.com/world/europe/aval...
# 3  https://www.straitstimes.com/asia/south-asia/h...
# 4  https://www.straitstimes.com/world/united-stat...
#
#                                      content summary  \
# 0  MUMBAI (REUTERS) - A Himalayan avalanche kille...
# 1  ZURICH (REUTERS) - One person was killed and f...
# 2  VIENNA (REUTERS) - An avalanche in an area of ...
# 3  NEW DELHI (REUTERS) - A Himalayan avalanche tr...
# 4  SALT LAKE CITY (NYTIMES) - Four back-country s...
#
#                                             keywords          class_name  \
# 0  kills, avalanche, defence, kameng, china, sold...  natural calamities
# 1  person, avalanche, tyrol, killed, days, skiers...  natural calamities
# 2  kills, avalanche, person, services, supervisor...  natural calamities
# 3  arunachal, avalanche, army, defence, team, chi...  natural calamities
# 4  avalanche, states, killed, skiers, saidthe, sa...  natural calamities
#
#                                    Preprocessed_Text  \
# 0  [mumbai, reuters, himalayan, avalanche, killed...
# 1  [zurich, reuters, one, person, killed, four, o...
# 2  [vienna, reuters, avalanche, area, austria, bo...
# 3  [new, delhi, reuters, himalayan, avalanche, tr...
# 4  [salt, lake, city, nytimes, four, back, countr...
#
#                                   Preprocessed_Text2
# 0  mumbai reuters himalayan avalanche killed seve...
# 1  zurich reuters one person killed four others i...
# 2  vienna reuters avalanche area austria borderin...
# 3  new delhi reuters himalayan avalanche trapped ...
# 4  salt lake city nytimes four back country skier...

# %%
X = df['Preprocessed_Text2']
y = df['class_name']

# %% [markdown]
# # Feature Extraction

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
tf_vec = TfidfVectorizer()
train_features = tf_vec.fit(X_train)
train_features = tf_vec.transform(X_train)
test_features = tf_vec.transform(X_test)

# %% [markdown]
# # Modelling

# %%
def fit_eval_model(model, train_features, y_train, test_features, y_test):
    
    """
    Function: train and evaluate a machine learning classifier.
    Args:
      model: machine learning classifier
      train_features: train data extracted features
      y_train: train data lables
      test_features: train data extracted features
      y_test: train data lables
    Return:
      results(dictionary): a dictionary of the model training time and classification report
    """
    results ={}
    
    # Start time
    start = time.time()
    # Train the model
    model.fit(train_features, y_train)
    # End time
    end = time.time()
    # Calculate the training time
    results['train_time'] = end - start
    
    # Test the model
    train_predicted = model.predict(train_features)
    test_predicted = model.predict(test_features)
    
     # Classification report
    results['classification_report'] = classification_report(y_test, test_predicted)
        
    return results

# %%
sv = svm.SVC()
ab = AdaBoostClassifier(random_state = 1)
gb = GradientBoostingClassifier(random_state = 1)
xgb = xgboost.XGBClassifier(random_state = 1)
tree = DecisionTreeClassifier()
nb = MultinomialNB()


# Fit and evaluate models
results = {}
for cls in [sv, ab, gb, xgb, tree, nb]:
    cls_name = cls.__class__.__name__
    results[cls_name] = {}
    results[cls_name] = fit_eval_model(cls, train_features, y_train, test_features, y_test)
# Out:
# C:\Users\Darren\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:44:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
for res in results:
    print (res)
    print()
    for i in results[res]:
        print (i, ':')
        print(results[res][i])
        print()
    print ('-----')
    print()
# Out:
# SVC
#
# train_time :
# 0.6494221687316895
#
# classification_report :
#                      precision    recall  f1-score   support
#
# Human health crises       0.97      0.87      0.92       110
#  natural calamities       0.92      0.98      0.95       154
#
#            accuracy                           0.94       264
#           macro avg       0.94      0.93      0.93       264
#        weighted avg       0.94      0.94      0.94       264
#
#
# -----
#
# AdaBoostClassifier
#
# train_time :
# 0.4564037322998047
#
# classification_report :
#                      precision    recall  f1-score   support
#
# Human health crises       0.95      0.86      0.90       110
#  natural calamities       0.91      0.97      0.94       154
#
#            accuracy                           0.92       264
#           macro avg       0.93      0.92      0.92       264
#        weighted avg       0.93      0.92      0.92       264
#
#
# -----
#
# GradientBoostingClassifier
#
# train_time :
# 1.673257827758789
#
# classification_report :
#                      precision    recall  f1-score   support
#
# Human health crises       0.97      0.89      0.93       110
#  natural calamities       0.93      0.98      0.95       154
#
#            accuracy                           0.94       264
#           macro avg       0.95      0.94      0.94       264
#        weighted avg       0.94      0.94      0.94       264
#
#
# -----
#
# XGBClassifier
#
# train_time :
# 0.5129103660583496
#
# classification_report :
#                      precision    recall  f1-score   support
#
# Human health crises       0.94      0.92      0.93       110
#  natural calamities       0.94      0.95      0.95       154
#
#            accuracy                           0.94       264
#           macro avg       0.94      0.94      0.94       264
#        weighted avg       0.94      0.94      0.94       264
#
#
# -----
#
# DecisionTreeClassifier
#
# train_time :
# 0.15162897109985352
#
# classification_report :
#                      precision    recall  f1-score   support
#
# Human health crises       0.90      0.93      0.91       110
#  natural calamities       0.95      0.93      0.94       154
#
#            accuracy                           0.93       264
#           macro avg       0.92      0.93      0.93       264
#        weighted avg       0.93      0.93      0.93       264
#
#
# -----
#
# MultinomialNB
#
# train_time :
# 0.00399017333984375
#
# classification_report :
#                      precision    recall  f1-score   support
#
# Human health crises       0.94      0.87      0.91       110
#  natural calamities       0.91      0.96      0.94       154
#
#            accuracy                           0.92       264
#           macro avg       0.93      0.92      0.92       264
#        weighted avg       0.93      0.92      0.92       264
#
#
# -----
